# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import itertools
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### 1. Carga de datos

# %%
def load_data(filepath):
    return pd.read_csv(filepath, parse_dates=['Date'])

# %% [markdown]
# ### 2. Division y tratamiento de datos

# %%
def create_sequences(data, target, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:(i + n_steps)])
        y.append(target[i + n_steps])
    return np.array(X), np.array(y)

# %%
def modify_data(data):
    result = None
    # print(data)

    # copy LMCADY_acu_5d_log into a new column ACU_5D and shift it by 5 days
    data['ACU_5D'] = data['LMCADY_acu_5d_log']
    data['ACU_5D'] = data['ACU_5D'].shift(5)

    data.dropna(inplace=True)

    result = data
    # print(result.head(10))
    return result

# %%
def prepare_data(df, target_column, n_steps):

    df = modify_data(df)

    # print(df.head(10))


    features = df.drop(columns=[target_column, 'LMCADY_std_5d_log'])
    print(features.head(10))
    features = features.drop(columns = ['Date'])

    # print features being used
    print("Features utilizados:",features.columns)

    target = df[target_column]

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    X, y = create_sequences(features_scaled, target, n_steps)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle = False)

    return X_train, X_test, y_train, y_test

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# # print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
# n_steps = 10
# # Preparación de los datos
# X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

# %% [markdown]
# ### 3. Arquitectura y compilacion

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
def build_model(input_shape, md_prm: dict):
    model = Sequential([
        Conv1D(filters=md_prm['filters']*2, kernel_size=md_prm['kernel_size'], activation=md_prm['activation'], input_shape=input_shape),
        Conv1D(filters=md_prm['filters'], kernel_size=md_prm['kernel_size'], activation=md_prm['activation']),
        MaxPooling1D(pool_size=md_prm['pool_size']),
        Dropout(md_prm['dropout']/2),
        Flatten(),
        Dense(md_prm['dense_units']*2, activation=md_prm['dense_activation']),
        Dense(md_prm['dense_units'], activation=md_prm['dense_activation']),
        Dense(1, activation = "linear")
    ])
    # puede ser 0.0005
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=[rmse])
    return model

# %% [markdown]
# ### 4. Entrenamiento del modelo

# %%
def train_model(model, X_train, y_train, epochs, batch_size, verbose):
    early_stopping = EarlyStopping(
        monitor             ='val_rmse',
        patience            =10,
        verbose             =1,
        restore_best_weights=True
    )
    history = model.fit(
        X_train, y_train,
        epochs          =epochs,
        batch_size      =batch_size,
        verbose         =verbose,
        validation_split=0.1,
        callbacks       =[early_stopping]
    )
    return history

# %% [markdown]
# ### 5. Evaluacion de resultado

# %%
def evaluate_model(model, X_test, y_test):
    loss = model.evaluate(X_test, y_test)
    print(f'Test Loss: {loss}')

# %%
def plot_history(history):
    # plotear loss de entrenamiento y validación
    figsize = (8,2)

    plt.figure(figsize=figsize)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    # otras metricas
    for key in history.history.keys():
        if key not in ['loss', 'val_loss', 'val_rmse']:
            plt.figure(figsize=figsize)
            plt.plot(history.history[key], label=f'Training {key}')
            plt.plot(history.history[f'val_{key}'], label=f'Validation {key}')
            plt.title(f'Model {key.capitalize()}')
            plt.ylabel(key.capitalize())
            plt.xlabel('Epoch')
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
def plot_predictions(y_true, y_pred, n, title="Prediction vs Actual Data"):
    # Asegurarse de que n no sea mayor que el número de puntos disponibles
    n = min(n, len(y_true), len(y_pred))

    # Usar slicing para obtener los últimos n valores
    y_true = y_true[-n:]
    y_pred = y_pred[-n:]

    plt.figure(figsize=(12, 2))
    plt.plot(y_true, label='Actual Values', marker='o', linestyle='-')
    plt.plot(y_pred, label='Predicted Values', marker='x', linestyle='--')

    plt.title(title)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# n_steps = 25
# target_column = 'LMCADY_acu_5d_log'
# X_train, X_test, y_train, y_test = prepare_data(df, target_column, n_steps)
# y_test.std()
# model = build_model(X_train.shape[1:])
# history = train_model(model, X_train, y_train, epochs=100, batch_size=16)
# evaluate_model(model, X_test, y_test)

# %%
# n_steps_options     = [25, 50, 100, 150, 200]
# batch_size_options  = [32, 64, 128, 256]
# n_steps_options = [10, 20, 30, 50]
n_steps_options = [24,25,26]
batch_size_options = [8, 16]
# n_steps_options     = [15]
# batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [128]
kernel_size_options     = [2]
pool_size_options       = [1]
dense_units_options     = [50, 100]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1]


model_params_combinations = list(itertools.product(
    filters_options, kernel_size_options, pool_size_options, dense_units_options,
    dense_activation_options, activation_options, dropout_options
))
target_column = 'LMCADY_acu_5d_log'

# %%
# number of iterations
n_iter = len(n_steps_options) * len(batch_size_options) * len(epochs_options) * len(model_params_combinations)
print(f'Total iterations: {n_iter}')
# Out:
# Total iterations: 12

# %%
def run_model_iterations():
    top_results = []

    i = 1
    for n_steps, batch_size, epochs, (filters, kernel_size, pool_size, dense_units, dense_activation, activation, dropout) in itertools.product(n_steps_options, batch_size_options, epochs_options, model_params_combinations):
        try:
            # Carga de datos
            df = load_data("./input/copper_log_returns_5d_final.csv")
            print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")

            # Preparación de los datos
            X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

            # print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}, y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

            # show a sample of X_train
            # print(f"X_train[1]: {X_train[1]}")
            # print("X_train[1] shape: ", X_train[1].shape)
            # print("X_train[2]: ", X_train[2])
            # print("X_train[2] shape: ", X_train[2].shape)
            # print("X_train",X_train)
            # print("X_train shape: ", X_train.shape)

            # Configuración de parámetros del modelo
            model_params = {
                'filters'           : filters,
                'kernel_size'       : kernel_size,
                'pool_size'         : pool_size,
                'dense_units'       : dense_units,
                'dense_activation'  : dense_activation,
                'activation'        : activation,
                'dropout'           : dropout
            }

            # Construcción y entrenamiento del modelo
            model   = build_model(X_train.shape[1:], model_params)
            print(model.summary())
            history = train_model(model, X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

            # Evaluación del modelo
            y_pred  = model.predict(X_test)
            # y_pred *= -1
            rmse_ob = sqrt(mean_squared_error(y_test, y_pred))
            std_dev = y_test.std()

            # diferencia entre rmse y desvstd
            difference = rmse_ob - std_dev

            # Guardar y ordenar resultados basados en la diferencia absoluta
            result = {
                'difference': difference,
                'rmse'      : rmse_ob,
                'std_dev'   : std_dev,
                'params'    : model_params,
                'history'   : history,
                'batch_size': batch_size,
                'n_steps'   : n_steps,
                'predictions': y_pred,
                'actuals'   : y_test
            }
            top_results.append(result)
            top_results = sorted(top_results, key=lambda x: x['difference'])[:10]

            print(f"\n{i}) RMSE: {rmse_ob:.6f}, Std Dev: {std_dev:.6f}, Difference: {difference:.6f}")
            print(f"Tested with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
            print(f"Model params: {model_params}")

        except Exception as e:
            print(f"An error occurred: {e}. Skipping this combination.")
        i += 1

    return top_results

# %%
top_3_results = run_model_iterations()
# Out:
# 1) Testing with n_steps=24, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_38 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_39 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_19 (MaxPooli  (None, 22, 128)           0
#  ng1D)
#
#  dropout_19 (Dropout)        (None, 22, 128)           0
#
#  flatten_19 (Flatten)        (None, 2816)              0
#
#  dense_57 (Dense)            (None, 100)               281700
#
#  dense_58 (Dense)            (None, 50)                5050
#
#  dense_59 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 357329 (1.36 MB)
# Trainable params: 357329 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 31.
# Epoch 41: early stopping
# 26/26 [==============================] - 1s 15ms/step
#
# 1) RMSE: 0.016577, Std Dev: 0.030758, Difference: -0.014181
# Tested with n_steps=24, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 2) Testing with n_steps=24, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_40 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_41 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_20 (MaxPooli  (None, 22, 128)           0
#  ng1D)
#
#  dropout_20 (Dropout)        (None, 22, 128)           0
#
#  flatten_20 (Flatten)        (None, 2816)              0
#
#  dense_60 (Dense)            (None, 200)               563400
#
#  dense_61 (Dense)            (None, 100)               20100
#
#  dense_62 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 37.
# Epoch 47: early stopping
# 26/26 [==============================] - 0s 693us/step
#
# 2) RMSE: 0.016116, Std Dev: 0.030758, Difference: -0.014642
# Tested with n_steps=24, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 3) Testing with n_steps=24, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_42 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_43 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_21 (MaxPooli  (None, 22, 128)           0
#  ng1D)
#
#  dropout_21 (Dropout)        (None, 22, 128)           0
#
#  flatten_21 (Flatten)        (None, 2816)              0
#
#  dense_63 (Dense)            (None, 100)               281700
#
#  dense_64 (Dense)            (None, 50)                5050
#
#  dense_65 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 357329 (1.36 MB)
# Trainable params: 357329 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 89.
# Epoch 99: early stopping
# 26/26 [==============================] - 0s 705us/step
#
# 3) RMSE: 0.016863, Std Dev: 0.030758, Difference: -0.013895
# Tested with n_steps=24, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 4) Testing with n_steps=24, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_44 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_45 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_22 (MaxPooli  (None, 22, 128)           0
#  ng1D)
#
#  dropout_22 (Dropout)        (None, 22, 128)           0
#
#  flatten_22 (Flatten)        (None, 2816)              0
#
#  dense_66 (Dense)            (None, 200)               563400
#
#  dense_67 (Dense)            (None, 100)               20100
#
#  dense_68 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 49.
# Epoch 59: early stopping
# 26/26 [==============================] - 0s 682us/step
#
# 4) RMSE: 0.016583, Std Dev: 0.030758, Difference: -0.014175
# Tested with n_steps=24, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 5) Testing with n_steps=25, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_46 (Conv1D)          (None, 24, 256)           4864
#
#  conv1d_47 (Conv1D)          (None, 23, 128)           65664
#
#  max_pooling1d_23 (MaxPooli  (None, 23, 128)           0
#  ng1D)
#
#  dropout_23 (Dropout)        (None, 23, 128)           0
#
#  flatten_23 (Flatten)        (None, 2944)              0
#
#  dense_69 (Dense)            (None, 100)               294500
#
#  dense_70 (Dense)            (None, 50)                5050
#
#  dense_71 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 370129 (1.41 MB)
# Trainable params: 370129 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 68.
# Epoch 78: early stopping
# 26/26 [==============================] - 0s 580us/step
#
# 5) RMSE: 0.016581, Std Dev: 0.030736, Difference: -0.014154
# Tested with n_steps=25, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 6) Testing with n_steps=25, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_48 (Conv1D)          (None, 24, 256)           4864
#
#  conv1d_49 (Conv1D)          (None, 23, 128)           65664
#
#  max_pooling1d_24 (MaxPooli  (None, 23, 128)           0
#  ng1D)
#
#  dropout_24 (Dropout)        (None, 23, 128)           0
#
#  flatten_24 (Flatten)        (None, 2944)              0
#
#  dense_72 (Dense)            (None, 200)               589000
#
#  dense_73 (Dense)            (None, 100)               20100
#
#  dense_74 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 679729 (2.59 MB)
# Trainable params: 679729 (2.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 38.
# Epoch 48: early stopping
# 26/26 [==============================] - 0s 716us/step
#
# 6) RMSE: 0.016579, Std Dev: 0.030736, Difference: -0.014156
# Tested with n_steps=25, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 7) Testing with n_steps=25, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_50 (Conv1D)          (None, 24, 256)           4864
#
#  conv1d_51 (Conv1D)          (None, 23, 128)           65664
#
#  max_pooling1d_25 (MaxPooli  (None, 23, 128)           0
#  ng1D)
#
#  dropout_25 (Dropout)        (None, 23, 128)           0
#
#  flatten_25 (Flatten)        (None, 2944)              0
#
#  dense_75 (Dense)            (None, 100)               294500
#
#  dense_76 (Dense)            (None, 50)                5050
#
#  dense_77 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 370129 (1.41 MB)
# Trainable params: 370129 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 85.
# Epoch 95: early stopping
# 26/26 [==============================] - 0s 567us/step
#
# 7) RMSE: 0.016453, Std Dev: 0.030736, Difference: -0.014283
# Tested with n_steps=25, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 8) Testing with n_steps=25, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_52 (Conv1D)          (None, 24, 256)           4864
#
#  conv1d_53 (Conv1D)          (None, 23, 128)           65664
#
#  max_pooling1d_26 (MaxPooli  (None, 23, 128)           0
#  ng1D)
#
#  dropout_26 (Dropout)        (None, 23, 128)           0
#
#  flatten_26 (Flatten)        (None, 2944)              0
#
#  dense_78 (Dense)            (None, 200)               589000
#
#  dense_79 (Dense)            (None, 100)               20100
#
#  dense_80 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 679729 (2.59 MB)
# Trainable params: 679729 (2.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 67.
# Epoch 77: early stopping
# 26/26 [==============================] - 0s 656us/step
#
# 8) RMSE: 0.016832, Std Dev: 0.030736, Difference: -0.013904
# Tested with n_steps=25, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 9) Testing with n_steps=26, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_54 (Conv1D)          (None, 25, 256)           4864
#
#  conv1d_55 (Conv1D)          (None, 24, 128)           65664
#
#  max_pooling1d_27 (MaxPooli  (None, 24, 128)           0
#  ng1D)
#
#  dropout_27 (Dropout)        (None, 24, 128)           0
#
#  flatten_27 (Flatten)        (None, 3072)              0
#
#  dense_81 (Dense)            (None, 100)               307300
#
#  dense_82 (Dense)            (None, 50)                5050
#
#  dense_83 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 382929 (1.46 MB)
# Trainable params: 382929 (1.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 25.
# Epoch 35: early stopping
# 26/26 [==============================] - 1s 15ms/step
#
# 9) RMSE: 0.017016, Std Dev: 0.030736, Difference: -0.013719
# Tested with n_steps=26, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 10) Testing with n_steps=26, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_56 (Conv1D)          (None, 25, 256)           4864
#
#  conv1d_57 (Conv1D)          (None, 24, 128)           65664
#
#  max_pooling1d_28 (MaxPooli  (None, 24, 128)           0
#  ng1D)
#
#  dropout_28 (Dropout)        (None, 24, 128)           0
#
#  flatten_28 (Flatten)        (None, 3072)              0
#
#  dense_84 (Dense)            (None, 200)               614600
#
#  dense_85 (Dense)            (None, 100)               20100
#
#  dense_86 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 705329 (2.69 MB)
# Trainable params: 705329 (2.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 23.
# Epoch 33: early stopping
# 26/26 [==============================] - 0s 737us/step
#
# 10) RMSE: 0.017010, Std Dev: 0.030736, Difference: -0.013725
# Tested with n_steps=26, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 11) Testing with n_steps=26, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_58 (Conv1D)          (None, 25, 256)           4864
#
#  conv1d_59 (Conv1D)          (None, 24, 128)           65664
#
#  max_pooling1d_29 (MaxPooli  (None, 24, 128)           0
#  ng1D)
#
#  dropout_29 (Dropout)        (None, 24, 128)           0
#
#  flatten_29 (Flatten)        (None, 3072)              0
#
#  dense_87 (Dense)            (None, 100)               307300
#
#  dense_88 (Dense)            (None, 50)                5050
#
#  dense_89 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 382929 (1.46 MB)
# Trainable params: 382929 (1.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 13.
# Epoch 23: early stopping
# 26/26 [==============================] - 0s 627us/step
#
# 11) RMSE: 0.018094, Std Dev: 0.030736, Difference: -0.012642
# Tested with n_steps=26, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 12) Testing with n_steps=26, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_60 (Conv1D)          (None, 25, 256)           4864
#
#  conv1d_61 (Conv1D)          (None, 24, 128)           65664
#
#  max_pooling1d_30 (MaxPooli  (None, 24, 128)           0
#  ng1D)
#
#  dropout_30 (Dropout)        (None, 24, 128)           0
#
#  flatten_30 (Flatten)        (None, 3072)              0
#
#  dense_90 (Dense)            (None, 200)               614600
#
#  dense_91 (Dense)            (None, 100)               20100
#
#  dense_92 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 705329 (2.69 MB)
# Trainable params: 705329 (2.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 40.
# Epoch 50: early stopping
# 26/26 [==============================] - 0s 778us/step
#
# 12) RMSE: 0.016979, Std Dev: 0.030736, Difference: -0.013756
# Tested with n_steps=26, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}

# %%
for i, result in enumerate(top_3_results, 1):
    rmse            = result['rmse']
    model_params    = result['params']
    history         = result['history']
    batch_size      = result['batch_size']
    n_steps         = result['n_steps']
    y_test          = result['actuals']
    y_pred          = result['predictions']
    diff = result['difference']

    print(f"\nTop {i} Model")
    print(f"Best RMSE: {rmse:.6f} vs. a std of {y_test.std():.6f}, diff = {diff:.6f}")
    print(f"Model parameters: {model_params}")
    print(f"n_steps: {n_steps}, batch_size: {batch_size}")

    # plot_history(history)

    plot_predictions(y_test, y_pred, 100, title=f"Top {i} Model Predictions vs Actual")
    # plot_predictions(y_test, y_pred*-1, 100, title=f"Top {i} Model Predictions vs Actual")

    # print the values of predictions and actuals one next to the other(only the first 10)
    # for pred, actual in zip(y_pred[:10], y_test[:10]):
    #     print(f"Predicted: {pred[0]:.6f}, Actual: {actual:.6f}")
# Out:
# Top 1 Model
# Best RMSE: 0.016116 vs. a std of 0.030758, diff = -0.014642
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 24, batch_size: 8
# Top 2 Model
# Best RMSE: 0.016453 vs. a std of 0.030736, diff = -0.014283
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 25, batch_size: 16
# Top 3 Model
# Best RMSE: 0.016577 vs. a std of 0.030758, diff = -0.014181
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 24, batch_size: 8
# Top 4 Model
# Best RMSE: 0.016583 vs. a std of 0.030758, diff = -0.014175
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 24, batch_size: 16
# Top 5 Model
# Best RMSE: 0.016579 vs. a std of 0.030736, diff = -0.014156
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 25, batch_size: 8
# Top 6 Model
# Best RMSE: 0.016581 vs. a std of 0.030736, diff = -0.014154
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 25, batch_size: 8
# Top 7 Model
# Best RMSE: 0.016832 vs. a std of 0.030736, diff = -0.013904
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 25, batch_size: 16
# Top 8 Model
# Best RMSE: 0.016863 vs. a std of 0.030758, diff = -0.013895
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 24, batch_size: 16
# Top 9 Model
# Best RMSE: 0.016979 vs. a std of 0.030736, diff = -0.013756
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 26, batch_size: 16
# Top 10 Model
# Best RMSE: 0.017010 vs. a std of 0.030736, diff = -0.013725
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 26, batch_size: 8

# %%
"""
n_steps_options     = [15]
batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64, 128, 256]
kernel_size_options     = [2, 3, 5]
pool_size_options       = [1, 2]
dense_units_options     = [50, 100, 150]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1, 0.2, 0.3]
"""
# Out:
# "\nn_steps_options     = [15]\nbatch_size_options  = [16]\nepochs_options      = [100]\n\nfilters_options         = [64, 128, 256]\nkernel_size_options     = [2, 3, 5]\npool_size_options       = [1, 2]\ndense_units_options     = [50, 100, 150]\n# dense_activation_options = ['relu', 'tanh']\ndense_activation_options = ['relu']\n# activation_options      = ['relu', 'tanh']\nactivation_options      = ['relu']\ndropout_options         = [0.1, 0.2, 0.3]\n"
