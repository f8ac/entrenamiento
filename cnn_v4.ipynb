# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import itertools
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-05-13 20:12:44.445733: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-13 20:12:44.465865: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-13 20:12:44.465881: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-13 20:12:44.466425: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-13 20:12:44.470015: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-13 20:12:44.823751: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### 1. Carga de datos

# %%
def load_data(filepath):
    return pd.read_csv(filepath, parse_dates=['Date'])

# %% [markdown]
# ### 2. Division y tratamiento de datos

# %%
def create_sequences(data, target, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:(i + n_steps)])
        y.append(target[i + n_steps])
    return np.array(X), np.array(y)

# %%
def modify_data(data):
    result = None
    # print(data)

    # copy LMCADY_acu_5d_log into a new column ACU_5D and shift it by 5 days
    data['ACU_5D'] = data['LMCADY_acu_5d_log']
    data['ACU_5D'] = data['ACU_5D'].shift(5)

    data.dropna(inplace=True)

    result = data
    # print(result.head(10))
    return result

# %%
def prepare_data(df, target_column, n_steps):

    df = modify_data(df)

    # print(df.head(10))


    features = df.drop(columns=[target_column, 'LMCADY_std_5d_log'])
    print(features.head(10))
    features = features.drop(columns = ['Date'])

    # print features being used
    print("Features utilizados:",features.columns)

    target = df[target_column]

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    X, y = create_sequences(features_scaled, target, n_steps)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle = False)

    return X_train, X_test, y_train, y_test

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# # print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
# n_steps = 10
# # Preparación de los datos
# X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

# %% [markdown]
# ### 3. Arquitectura y compilacion

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
def build_model(input_shape, md_prm: dict):
    model = Sequential([
        Conv1D(filters=md_prm['filters']*2, kernel_size=md_prm['kernel_size'], activation=md_prm['activation'], input_shape=input_shape),
        Conv1D(filters=md_prm['filters'], kernel_size=md_prm['kernel_size'], activation=md_prm['activation']),
        MaxPooling1D(pool_size=md_prm['pool_size']),
        Dropout(md_prm['dropout']/2),
        Flatten(),
        Dense(md_prm['dense_units']*2, activation=md_prm['dense_activation']),
        Dense(md_prm['dense_units'], activation=md_prm['dense_activation']),
        Dense(1, activation = "linear")
    ])
    # puede ser 0.0005
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=[rmse])
    return model

# %% [markdown]
# ### 4. Entrenamiento del modelo

# %%
def train_model(model, X_train, y_train, epochs, batch_size, verbose):
    early_stopping = EarlyStopping(
        monitor             ='val_rmse',
        patience            =10,
        verbose             =1,
        restore_best_weights=True
    )
    history = model.fit(
        X_train, y_train,
        epochs          =epochs,
        batch_size      =batch_size,
        verbose         =verbose,
        validation_split=0.1,
        callbacks       =[early_stopping]
    )
    return history

# %% [markdown]
# ### 5. Evaluacion de resultado

# %%
def evaluate_model(model, X_test, y_test):
    loss = model.evaluate(X_test, y_test)
    print(f'Test Loss: {loss}')

# %%
def plot_history(history):
    # plotear loss de entrenamiento y validación
    figsize = (8,2)

    plt.figure(figsize=figsize)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    # otras metricas
    for key in history.history.keys():
        if key not in ['loss', 'val_loss', 'val_rmse']:
            plt.figure(figsize=figsize)
            plt.plot(history.history[key], label=f'Training {key}')
            plt.plot(history.history[f'val_{key}'], label=f'Validation {key}')
            plt.title(f'Model {key.capitalize()}')
            plt.ylabel(key.capitalize())
            plt.xlabel('Epoch')
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
def plot_predictions(y_true, y_pred, n, title="Prediction vs Actual Data", markersize=4):
    # Asegurarse de que n no sea mayor que el número de puntos disponibles
    n = min(n, len(y_true), len(y_pred))

    # Usar slicing para obtener los últimos n valores
    y_true = y_true[-n:]
    y_pred = y_pred[-n:]

    plt.figure(figsize=(12, 2))
    plt.plot(y_true, label='Actual Values', marker='o', linestyle='-', markersize=markersize)
    plt.plot(y_pred, label='Predicted Values', marker='x', linestyle='--', markersize=markersize)

    plt.axhline(y=0, color='gray', linestyle='--', linewidth=0.7) 

    plt.title(title)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# n_steps = 25
# target_column = 'LMCADY_acu_5d_log'
# X_train, X_test, y_train, y_test = prepare_data(df, target_column, n_steps)
# y_test.std()
# model = build_model(X_train.shape[1:])
# history = train_model(model, X_train, y_train, epochs=100, batch_size=16)
# evaluate_model(model, X_test, y_test)

# %%
# n_steps_options     = [25, 50, 100, 150, 200]
# batch_size_options  = [32, 64, 128, 256]
n_steps_options = [24]
batch_size_options = [8, 16]
# n_steps_options     = [15]
# batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64,128,256]
kernel_size_options     = [2]
pool_size_options       = [1]
dense_units_options     = [100]
dense_activation_options = ['tanh']
# dense_activation_options = ['relu']
activation_options      = ['tanh']
# activation_options      = ['relu']
dropout_options         = [0.1, 0.2]


model_params_combinations = list(itertools.product(
    filters_options, 
    kernel_size_options, 
    pool_size_options, 
    dense_units_options,
    dense_activation_options, 
    activation_options, 
    dropout_options
))
target_column = 'LMCADY_acu_5d_log'

# %%
# number of iterations
n_iter = len(n_steps_options) * len(batch_size_options) * len(epochs_options) * len(model_params_combinations)
print(f'Total iterations: {n_iter}')
# Out:
# Total iterations: 12

# %%
def run_model_iterations():
    top_results = []

    i = 1
    for n_steps, batch_size, epochs, (filters, kernel_size, pool_size, dense_units, dense_activation, activation, dropout) in itertools.product(n_steps_options, batch_size_options, epochs_options, model_params_combinations):
        try:
            # Carga de datos
            df = load_data("./input/copper_log_returns_5d_final.csv")
            print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")

            # Preparación de los datos
            X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

            # print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}, y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

            # show a sample of X_train
            # print(f"X_train[1]: {X_train[1]}")
            # print("X_train[1] shape: ", X_train[1].shape)
            # print("X_train[2]: ", X_train[2])
            # print("X_train[2] shape: ", X_train[2].shape)
            # print("X_train",X_train)
            # print("X_train shape: ", X_train.shape)

            # Configuración de parámetros del modelo
            model_params = {
                'filters'           : filters,
                'kernel_size'       : kernel_size,
                'pool_size'         : pool_size,
                'dense_units'       : dense_units,
                'dense_activation'  : dense_activation,
                'activation'        : activation,
                'dropout'           : dropout
            }

            # Construcción y entrenamiento del modelo
            model   = build_model(X_train.shape[1:], model_params)
            print(model.summary())
            history = train_model(model, X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

            # Evaluación del modelo
            y_pred  = model.predict(X_test)
            # y_pred *= -1
            rmse_ob = sqrt(mean_squared_error(y_test, y_pred))
            std_dev = y_test.std()

            # diferencia entre rmse y desvstd
            difference = rmse_ob - std_dev

            # Guardar y ordenar resultados basados en la diferencia absoluta
            result = {
                'difference': difference,
                'rmse'      : rmse_ob,
                'std_dev'   : std_dev,
                'params'    : model_params,
                'history'   : history,
                'batch_size': batch_size,
                'n_steps'   : n_steps,
                'predictions': y_pred,
                'actuals'   : y_test
            }
            top_results.append(result)
            top_results = sorted(top_results, key=lambda x: x['difference'])[:10]

            print(f"\n{i}) RMSE: {rmse_ob:.6f}, Std Dev: {std_dev:.6f}, Difference: {difference:.6f}")
            print(f"Tested with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
            print(f"Model params: {model_params}")

        except Exception as e:
            print(f"An error occurred: {e}. Skipping this combination.")
        i += 1

    return top_results

# %%
top_3_results = run_model_iterations()
# Out:
# 1) Testing with n_steps=24, batch_size=8, epochs=100, filters=64
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 23, 128)           2432
#
#  conv1d_1 (Conv1D)           (None, 22, 64)            16448
#
#  max_pooling1d (MaxPooling1  (None, 22, 64)            0
#  D)
#
#  dropout (Dropout)           (None, 22, 64)            0
#
#  flatten (Flatten)           (None, 1408)              0
#
#  dense (Dense)               (None, 200)               281800
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 320881 (1.22 MB)
# Trainable params: 320881 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-05-13 20:12:45.532560: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:45.551591: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:45.551717: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:45.553479: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:45.553553: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:45.553598: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:46.258556: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:46.258656: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:46.258712: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 20:12:46.258758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7992 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# None
# 2024-05-13 20:12:47.780032: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-05-13 20:12:48.261291: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-13 20:12:48.634652: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-13 20:12:49.029898: I external/local_xla/xla/service/service.cc:168] XLA service 0x7bd9100134f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-13 20:12:49.029913: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-05-13 20:12:49.033102: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715649169.088426 1672121 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Restoring model weights from the end of the best epoch: 37.
# Epoch 47: early stopping
# 26/26 [==============================] - 1s 13ms/step
#
# 1) RMSE: 0.016384, Std Dev: 0.030758, Difference: -0.014374
# Tested with n_steps=24, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 2) Testing with n_steps=24, batch_size=8, epochs=100, filters=64
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 23, 128)           2432
#
#  conv1d_3 (Conv1D)           (None, 22, 64)            16448
#
#  max_pooling1d_1 (MaxPoolin  (None, 22, 64)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 22, 64)            0
#
#  flatten_1 (Flatten)         (None, 1408)              0
#
#  dense_3 (Dense)             (None, 200)               281800
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 320881 (1.22 MB)
# Trainable params: 320881 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 32.
# Epoch 42: early stopping
# 26/26 [==============================] - 0s 654us/step
#
# 2) RMSE: 0.016639, Std Dev: 0.030758, Difference: -0.014118
# Tested with n_steps=24, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
#
# 3) Testing with n_steps=24, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 23, 256)           4864
#
#  conv1d_5 (Conv1D)           (None, 22, 128)           65664
#
#  max_pooling1d_2 (MaxPoolin  (None, 22, 128)           0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 22, 128)           0
#
#  flatten_2 (Flatten)         (None, 2816)              0
#
#  dense_6 (Dense)             (None, 200)               563400
#
#  dense_7 (Dense)             (None, 100)               20100
#
#  dense_8 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 21.
# Epoch 31: early stopping
# 26/26 [==============================] - 1s 15ms/step
#
# 3) RMSE: 0.017873, Std Dev: 0.030758, Difference: -0.012885
# Tested with n_steps=24, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 4) Testing with n_steps=24, batch_size=8, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 23, 256)           4864
#
#  conv1d_7 (Conv1D)           (None, 22, 128)           65664
#
#  max_pooling1d_3 (MaxPoolin  (None, 22, 128)           0
#  g1D)
#
#  dropout_3 (Dropout)         (None, 22, 128)           0
#
#  flatten_3 (Flatten)         (None, 2816)              0
#
#  dense_9 (Dense)             (None, 200)               563400
#
#  dense_10 (Dense)            (None, 100)               20100
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 38.
# Epoch 48: early stopping
# 26/26 [==============================] - 0s 787us/step
#
# 4) RMSE: 0.016179, Std Dev: 0.030758, Difference: -0.014579
# Tested with n_steps=24, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
#
# 5) Testing with n_steps=24, batch_size=8, epochs=100, filters=256
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 23, 512)           9728
#
#  conv1d_9 (Conv1D)           (None, 22, 256)           262400
#
#  max_pooling1d_4 (MaxPoolin  (None, 22, 256)           0
#  g1D)
#
#  dropout_4 (Dropout)         (None, 22, 256)           0
#
#  flatten_4 (Flatten)         (None, 5632)              0
#
#  dense_12 (Dense)            (None, 200)               1126600
#
#  dense_13 (Dense)            (None, 100)               20100
#
#  dense_14 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1418929 (5.41 MB)
# Trainable params: 1418929 (5.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 8.
# Epoch 18: early stopping
# 26/26 [==============================] - 1s 16ms/step
#
# 5) RMSE: 0.020182, Std Dev: 0.030758, Difference: -0.010576
# Tested with n_steps=24, batch_size=8, epochs=100, filters=256
# Model params: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 6) Testing with n_steps=24, batch_size=8, epochs=100, filters=256
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 23, 512)           9728
#
#  conv1d_11 (Conv1D)          (None, 22, 256)           262400
#
#  max_pooling1d_5 (MaxPoolin  (None, 22, 256)           0
#  g1D)
#
#  dropout_5 (Dropout)         (None, 22, 256)           0
#
#  flatten_5 (Flatten)         (None, 5632)              0
#
#  dense_15 (Dense)            (None, 200)               1126600
#
#  dense_16 (Dense)            (None, 100)               20100
#
#  dense_17 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1418929 (5.41 MB)
# Trainable params: 1418929 (5.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 8.
# Epoch 18: early stopping
# 26/26 [==============================] - 0s 1ms/step
#
# 6) RMSE: 0.017536, Std Dev: 0.030758, Difference: -0.013222
# Tested with n_steps=24, batch_size=8, epochs=100, filters=256
# Model params: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
#
# 7) Testing with n_steps=24, batch_size=16, epochs=100, filters=64
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 23, 128)           2432
#
#  conv1d_13 (Conv1D)          (None, 22, 64)            16448
#
#  max_pooling1d_6 (MaxPoolin  (None, 22, 64)            0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 22, 64)            0
#
#  flatten_6 (Flatten)         (None, 1408)              0
#
#  dense_18 (Dense)            (None, 200)               281800
#
#  dense_19 (Dense)            (None, 100)               20100
#
#  dense_20 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 320881 (1.22 MB)
# Trainable params: 320881 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 54.
# Epoch 64: early stopping
# 26/26 [==============================] - 0s 698us/step
#
# 7) RMSE: 0.016998, Std Dev: 0.030758, Difference: -0.013760
# Tested with n_steps=24, batch_size=16, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 8) Testing with n_steps=24, batch_size=16, epochs=100, filters=64
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 23, 128)           2432
#
#  conv1d_15 (Conv1D)          (None, 22, 64)            16448
#
#  max_pooling1d_7 (MaxPoolin  (None, 22, 64)            0
#  g1D)
#
#  dropout_7 (Dropout)         (None, 22, 64)            0
#
#  flatten_7 (Flatten)         (None, 1408)              0
#
#  dense_21 (Dense)            (None, 200)               281800
#
#  dense_22 (Dense)            (None, 100)               20100
#
#  dense_23 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 320881 (1.22 MB)
# Trainable params: 320881 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 52.
# Epoch 62: early stopping
# 26/26 [==============================] - 0s 692us/step
#
# 8) RMSE: 0.016562, Std Dev: 0.030758, Difference: -0.014196
# Tested with n_steps=24, batch_size=16, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
#
# 9) Testing with n_steps=24, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_17 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_8 (MaxPoolin  (None, 22, 128)           0
#  g1D)
#
#  dropout_8 (Dropout)         (None, 22, 128)           0
#
#  flatten_8 (Flatten)         (None, 2816)              0
#
#  dense_24 (Dense)            (None, 200)               563400
#
#  dense_25 (Dense)            (None, 100)               20100
#
#  dense_26 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 15.
# Epoch 25: early stopping
# 26/26 [==============================] - 0s 728us/step
#
# 9) RMSE: 0.019333, Std Dev: 0.030758, Difference: -0.011425
# Tested with n_steps=24, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 10) Testing with n_steps=24, batch_size=16, epochs=100, filters=128
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 23, 256)           4864
#
#  conv1d_19 (Conv1D)          (None, 22, 128)           65664
#
#  max_pooling1d_9 (MaxPoolin  (None, 22, 128)           0
#  g1D)
#
#  dropout_9 (Dropout)         (None, 22, 128)           0
#
#  flatten_9 (Flatten)         (None, 2816)              0
#
#  dense_27 (Dense)            (None, 200)               563400
#
#  dense_28 (Dense)            (None, 100)               20100
#
#  dense_29 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 654129 (2.50 MB)
# Trainable params: 654129 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 17.
# Epoch 27: early stopping
# 26/26 [==============================] - 0s 631us/step
#
# 10) RMSE: 0.018425, Std Dev: 0.030758, Difference: -0.012333
# Tested with n_steps=24, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
#
# 11) Testing with n_steps=24, batch_size=16, epochs=100, filters=256
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 23, 512)           9728
#
#  conv1d_21 (Conv1D)          (None, 22, 256)           262400
#
#  max_pooling1d_10 (MaxPooli  (None, 22, 256)           0
#  ng1D)
#
#  dropout_10 (Dropout)        (None, 22, 256)           0
#
#  flatten_10 (Flatten)        (None, 5632)              0
#
#  dense_30 (Dense)            (None, 200)               1126600
#
#  dense_31 (Dense)            (None, 100)               20100
#
#  dense_32 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1418929 (5.41 MB)
# Trainable params: 1418929 (5.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 13.
# Epoch 23: early stopping
# 26/26 [==============================] - 0s 1ms/step
#
# 11) RMSE: 0.017867, Std Dev: 0.030758, Difference: -0.012891
# Tested with n_steps=24, batch_size=16, epochs=100, filters=256
# Model params: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
#
# 12) Testing with n_steps=24, batch_size=16, epochs=100, filters=256
#          Date  LMCADS03    LMCADY       DXY       SPX      BCOM      MXWD  \
# 5  2003-01-09  0.010936  0.011509  0.000687  0.019211  0.013934  0.014910
# 6  2003-01-10 -0.010936 -0.011664 -0.006989 -0.000011 -0.014158  0.002825
# 7  2003-01-13  0.007000  0.006463  0.002368 -0.001413  0.003660  0.000755
# 8  2003-01-14  0.011160  0.010982 -0.002566  0.005813 -0.000474  0.007021
# 9  2003-01-15  0.006577  0.006050  0.001284 -0.014531  0.009620 -0.010854
# 10 2003-01-16  0.004163  0.004964 -0.005442 -0.003950  0.008511 -0.003036
# 11 2003-01-17 -0.009241 -0.009346 -0.002384 -0.014116 -0.000756 -0.012493
# 12 2003-01-20  0.013978  0.013837 -0.000796  0.000000  0.000000 -0.004887
# 13 2003-01-21 -0.001182 -0.001046 -0.002392 -0.015827  0.001818 -0.010992
# 14 2003-01-22  0.004720  0.004922  0.000000 -0.010487  0.005678 -0.011114
#
#          XAU       XAG    ACU_5D
# 5  -0.002492 -0.002064  0.040542
# 6   0.005654  0.004741  0.015400
# 7  -0.000564 -0.006809  0.011601
# 8  -0.009067 -0.014599  0.027062
# 9  -0.001709  0.001050  0.023340
# 10  0.018922  0.013549  0.016794
# 11 -0.002521 -0.006231  0.019112
# 12 -0.002246 -0.002086  0.026487
# 13  0.005606  0.005206  0.014458
# 14  0.011395  0.009302  0.013331
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_22 (Conv1D)          (None, 23, 512)           9728
#
#  conv1d_23 (Conv1D)          (None, 22, 256)           262400
#
#  max_pooling1d_11 (MaxPooli  (None, 22, 256)           0
#  ng1D)
#
#  dropout_11 (Dropout)        (None, 22, 256)           0
#
#  flatten_11 (Flatten)        (None, 5632)              0
#
#  dense_33 (Dense)            (None, 200)               1126600
#
#  dense_34 (Dense)            (None, 100)               20100
#
#  dense_35 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1418929 (5.41 MB)
# Trainable params: 1418929 (5.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 15.
# Epoch 25: early stopping
# 26/26 [==============================] - 0s 1ms/step
#
# 12) RMSE: 0.017879, Std Dev: 0.030758, Difference: -0.012879
# Tested with n_steps=24, batch_size=16, epochs=100, filters=256
# Model params: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}

# %%
for i, result in enumerate(top_3_results, 1):
    rmse            = result['rmse']
    model_params    = result['params']
    history         = result['history']
    batch_size      = result['batch_size']
    n_steps         = result['n_steps']
    y_test          = result['actuals']
    y_pred          = result['predictions']
    diff = result['difference']

    print(f"\nTop {i} Model")
    print(f"Best RMSE: {rmse:.6f} vs. a std of {y_test.std():.6f}, diff = {diff:.6f}")
    print(f"Model parameters: {model_params}")
    print(f"n_steps: {n_steps}, batch_size: {batch_size}")

    # plot_history(history)

    plot_predictions(y_test, y_pred, 100, title=f"Top {i} Model Predictions vs Actual")
    # plot_predictions(y_test, y_pred*-1, 100, title=f"Top {i} Model Predictions vs Actual")

    # print the values of predictions and actuals one next to the other(only the first 10)
    # for pred, actual in zip(y_pred[:10], y_test[:10]):
    #     print(f"Predicted: {pred[0]:.6f}, Actual: {actual:.6f}")
# Out:
# Top 1 Model
# Best RMSE: 0.016179 vs. a std of 0.030758, diff = -0.014579
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 8
# Top 2 Model
# Best RMSE: 0.016384 vs. a std of 0.030758, diff = -0.014374
# Model parameters: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
# n_steps: 24, batch_size: 8
# Top 3 Model
# Best RMSE: 0.016562 vs. a std of 0.030758, diff = -0.014196
# Model parameters: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 16
# Top 4 Model
# Best RMSE: 0.016639 vs. a std of 0.030758, diff = -0.014118
# Model parameters: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 8
# Top 5 Model
# Best RMSE: 0.016998 vs. a std of 0.030758, diff = -0.013760
# Model parameters: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
# n_steps: 24, batch_size: 16
# Top 6 Model
# Best RMSE: 0.017536 vs. a std of 0.030758, diff = -0.013222
# Model parameters: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 8
# Top 7 Model
# Best RMSE: 0.017867 vs. a std of 0.030758, diff = -0.012891
# Model parameters: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
# n_steps: 24, batch_size: 16
# Top 8 Model
# Best RMSE: 0.017873 vs. a std of 0.030758, diff = -0.012885
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.1}
# n_steps: 24, batch_size: 8
# Top 9 Model
# Best RMSE: 0.017879 vs. a std of 0.030758, diff = -0.012879
# Model parameters: {'filters': 256, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 16
# Top 10 Model
# Best RMSE: 0.018425 vs. a std of 0.030758, diff = -0.012333
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'tanh', 'activation': 'tanh', 'dropout': 0.2}
# n_steps: 24, batch_size: 16

# %%
"""
n_steps_options     = [15]
batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64, 128, 256]
kernel_size_options     = [2, 3, 5]
pool_size_options       = [1, 2]
dense_units_options     = [50, 100, 150]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1, 0.2, 0.3]
"""
# Out:
# "\nn_steps_options     = [15]\nbatch_size_options  = [16]\nepochs_options      = [100]\n\nfilters_options         = [64, 128, 256]\nkernel_size_options     = [2, 3, 5]\npool_size_options       = [1, 2]\ndense_units_options     = [50, 100, 150]\n# dense_activation_options = ['relu', 'tanh']\ndense_activation_options = ['relu']\n# activation_options      = ['relu', 'tanh']\nactivation_options      = ['relu']\ndropout_options         = [0.1, 0.2, 0.3]\n"
