# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import itertools
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-05-08 21:26:05.853315: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-08 21:26:05.873488: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 21:26:05.873504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 21:26:05.874051: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 21:26:05.877550: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-08 21:26:06.232168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### 1. Carga de datos

# %%
def load_data(filepath):
    return pd.read_csv(filepath, parse_dates=['Date'])

# %% [markdown]
# ### 2. Division y tratamiento de datos

# %%
def create_sequences(data, target, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:(i + n_steps)])
        y.append(target[i + n_steps])
    return np.array(X), np.array(y)

# %%
def modify_data(data):
    result = None
    # print(data)

    # copy LMCADY_acu_5d_log into a new column ACU_5D and shift it by 5 days
    data['ACU_5D'] = data['LMCADY_acu_5d_log']
    data['ACU_5D'] = data['ACU_5D'].shift(5)

    data.dropna(inplace=True)

    result = data
    # print(result.head(10))
    return result

# %%
def prepare_data(df, target_column, n_steps):

    df = modify_data(df)


    features = df.drop(columns=[target_column, 'LMCADY_std_5d_log'])
    features = features.drop(columns = ['Date'])

    # print features being used
    print("Features utilizados:",features.columns)

    target = df[target_column]

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    X, y = create_sequences(features_scaled, target, n_steps)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle = False)

    return X_train, X_test, y_train, y_test

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# # print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
# n_steps = 10
# # Preparación de los datos
# X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

# %% [markdown]
# ### 3. Arquitectura y compilacion

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
def build_model(input_shape, md_prm: dict):
    model = Sequential([
        Conv1D(filters=md_prm['filters']*2, kernel_size=md_prm['kernel_size'], activation=md_prm['activation'], input_shape=input_shape),
        Conv1D(filters=md_prm['filters'], kernel_size=md_prm['kernel_size'], activation=md_prm['activation']),
        MaxPooling1D(pool_size=md_prm['pool_size']),
        Dropout(md_prm['dropout']/2),
        Flatten(),
        Dense(md_prm['dense_units']*2, activation=md_prm['dense_activation']),
        Dense(md_prm['dense_units'], activation=md_prm['dense_activation']),
        Dense(1, activation = "linear")
    ])
    # puede ser 0.0005
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=[rmse])
    return model

# %% [markdown]
# ### 4. Entrenamiento del modelo

# %%
def train_model(model, X_train, y_train, epochs, batch_size, verbose):
    early_stopping = EarlyStopping(
        monitor             ='val_rmse',
        patience            =10,
        verbose             =1,
        restore_best_weights=True
    )
    history = model.fit(
        X_train, y_train,
        epochs          =epochs,
        batch_size      =batch_size,
        verbose         =verbose,
        validation_split=0.1,
        callbacks       =[early_stopping]
    )
    return history

# %% [markdown]
# ### 5. Evaluacion de resultado

# %%
def evaluate_model(model, X_test, y_test):
    loss = model.evaluate(X_test, y_test)
    print(f'Test Loss: {loss}')

# %%
def plot_history(history):
    # plotear loss de entrenamiento y validación
    figsize = (8,2)

    plt.figure(figsize=figsize)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    # otras metricas
    for key in history.history.keys():
        if key not in ['loss', 'val_loss', 'val_rmse']:
            plt.figure(figsize=figsize)
            plt.plot(history.history[key], label=f'Training {key}')
            plt.plot(history.history[f'val_{key}'], label=f'Validation {key}')
            plt.title(f'Model {key.capitalize()}')
            plt.ylabel(key.capitalize())
            plt.xlabel('Epoch')
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
def plot_predictions(y_true, y_pred, n, title="Prediction vs Actual Data"):
    # Asegurarse de que n no sea mayor que el número de puntos disponibles
    n = min(n, len(y_true), len(y_pred))

    # Usar slicing para obtener los últimos n valores
    y_true = y_true[-n:]
    y_pred = y_pred[-n:]

    plt.figure(figsize=(12, 2))
    plt.plot(y_true, label='Actual Values', marker='o', linestyle='-')
    plt.plot(y_pred, label='Predicted Values', marker='x', linestyle='--')

    plt.title(title)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# n_steps = 25
# target_column = 'LMCADY_acu_5d_log'
# X_train, X_test, y_train, y_test = prepare_data(df, target_column, n_steps)
# y_test.std()
# model = build_model(X_train.shape[1:])
# history = train_model(model, X_train, y_train, epochs=100, batch_size=16)
# evaluate_model(model, X_test, y_test)

# %%
# n_steps_options     = [25, 50, 100, 150, 200]
# batch_size_options  = [32, 64, 128, 256]
n_steps_options = [10, 20, 30, 50]
batch_size_options = [8, 16, 32]
# n_steps_options     = [15]
# batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64, 128]
kernel_size_options     = [2, 3, 5]
pool_size_options       = [1, 2]
dense_units_options     = [50, 100]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1, 0.2]


model_params_combinations = list(itertools.product(
    filters_options, kernel_size_options, pool_size_options, dense_units_options,
    dense_activation_options, activation_options, dropout_options
))
target_column = 'LMCADY_acu_5d_log'

# %%
# number of iterations
n_iter = len(n_steps_options) * len(batch_size_options) * len(epochs_options) * len(model_params_combinations)
print(f'Total iterations: {n_iter}')
# Out:
# Total iterations: 576

# %%
def run_model_iterations():
    top_results = []

    i = 1
    for n_steps, batch_size, epochs, (filters, kernel_size, pool_size, dense_units, dense_activation, activation, dropout) in itertools.product(n_steps_options, batch_size_options, epochs_options, model_params_combinations):
        try:
            # Carga de datos
            df = load_data("./input/copper_log_returns_5d_final.csv")
            print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")

            # Preparación de los datos
            X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

            # print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}, y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

            # show a sample of X_train
            # print(f"X_train[1]: {X_train[1]}")
            # print("X_train[1] shape: ", X_train[1].shape)
            # print("X_train[2]: ", X_train[2])
            # print("X_train[2] shape: ", X_train[2].shape)
            # print("X_train",X_train)
            # print("X_train shape: ", X_train.shape)

            # Configuración de parámetros del modelo
            model_params = {
                'filters'           : filters,
                'kernel_size'       : kernel_size,
                'pool_size'         : pool_size,
                'dense_units'       : dense_units,
                'dense_activation'  : dense_activation,
                'activation'        : activation,
                'dropout'           : dropout
            }

            # Construcción y entrenamiento del modelo
            model   = build_model(X_train.shape[1:], model_params)
            print(model.summary())
            history = train_model(model, X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

            # Evaluación del modelo
            y_pred  = model.predict(X_test)
            # y_pred *= -1
            rmse_ob = sqrt(mean_squared_error(y_test, y_pred))
            std_dev = y_test.std()

            # diferencia entre rmse y desvstd
            difference = rmse_ob - std_dev

            # Guardar y ordenar resultados basados en la diferencia absoluta
            result = {
                'difference': difference,
                'rmse'      : rmse_ob,
                'std_dev'   : std_dev,
                'params'    : model_params,
                'history'   : history,
                'batch_size': batch_size,
                'n_steps'   : n_steps,
                'predictions': y_pred,
                'actuals'   : y_test
            }
            top_results.append(result)
            top_results = sorted(top_results, key=lambda x: x['difference'])[:10]

            print(f"\n{i}) RMSE: {rmse_ob:.6f}, Std Dev: {std_dev:.6f}, Difference: {difference:.6f}")
            print(f"Tested with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
            print(f"Model params: {model_params}")

        except Exception as e:
            print(f"An error occurred: {e}. Skipping this combination.")
        i += 1

    return top_results

# %%
top_3_results = run_model_iterations()
# Out:
# 1) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 9, 128)            2432
#
#  conv1d_1 (Conv1D)           (None, 8, 64)             16448
#
#  max_pooling1d (MaxPooling1  (None, 8, 64)             0
#  D)
#
#  dropout (Dropout)           (None, 8, 64)             0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 100)               51300
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 75281 (294.07 KB)
# Trainable params: 75281 (294.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-05-08 21:26:06.919062: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:06.937903: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:06.938018: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:06.938949: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:06.939021: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:06.939068: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:07.579159: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:07.579273: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:07.579330: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 21:26:07.579376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7992 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# None
# 2024-05-08 21:26:09.094066: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-05-08 21:26:09.574866: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-08 21:26:09.740283: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-08 21:26:10.404216: I external/local_xla/xla/service/service.cc:168] XLA service 0x7aa59c00f400 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-08 21:26:10.404231: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-05-08 21:26:10.407390: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715221570.461148  364219 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Restoring model weights from the end of the best epoch: 16.
# Epoch 26: early stopping
# Epoch 26: early stopping
# 26/26 [==============================] - 1s 13ms/step
#
# 1) RMSE: 0.018418, Std Dev: 0.030739, Difference: -0.012322
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 2) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 9, 128)            2432
#
#  conv1d_3 (Conv1D)           (None, 8, 64)             16448
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 64)             0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 8, 64)             0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 100)               51300
#
#  dense_4 (Dense)             (None, 50)                5050
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 75281 (294.07 KB)
# Trainable params: 75281 (294.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 37.
# Epoch 47: early stopping
# 26/26 [==============================] - 0s 606us/step
#
# 2) RMSE: 0.018008, Std Dev: 0.030739, Difference: -0.012732
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 3) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 9, 128)            2432
#
#  conv1d_5 (Conv1D)           (None, 8, 64)             16448
#
#  max_pooling1d_2 (MaxPoolin  (None, 8, 64)             0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 8, 64)             0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 200)               102600
#
#  dense_7 (Dense)             (None, 100)               20100
#
#  dense_8 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 141681 (553.44 KB)
# Trainable params: 141681 (553.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 58.
# Epoch 68: early stopping
# 26/26 [==============================] - 0s 611us/step
#
# 3) RMSE: 0.017401, Std Dev: 0.030739, Difference: -0.013338
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 4) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 9, 128)            2432
#
#  conv1d_7 (Conv1D)           (None, 8, 64)             16448
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 64)             0
#  g1D)
#
#  dropout_3 (Dropout)         (None, 8, 64)             0
#
#  flatten_3 (Flatten)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 200)               102600
#
#  dense_10 (Dense)            (None, 100)               20100
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 141681 (553.44 KB)
# Trainable params: 141681 (553.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 25.
# Epoch 35: early stopping
# 26/26 [==============================] - 0s 660us/step
#
# 4) RMSE: 0.017549, Std Dev: 0.030739, Difference: -0.013190
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 5) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 9, 128)            2432
#
#  conv1d_9 (Conv1D)           (None, 8, 64)             16448
#
#  max_pooling1d_4 (MaxPoolin  (None, 4, 64)             0
#  g1D)
#
#  dropout_4 (Dropout)         (None, 4, 64)             0
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 100)               25700
#
#  dense_13 (Dense)            (None, 50)                5050
#
#  dense_14 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 49681 (194.07 KB)
# Trainable params: 49681 (194.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 31.
# Epoch 41: early stopping
# 26/26 [==============================] - 0s 695us/step
#
# 5) RMSE: 0.017754, Std Dev: 0.030739, Difference: -0.012985
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 6) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 9, 128)            2432
#
#  conv1d_11 (Conv1D)          (None, 8, 64)             16448
#
#  max_pooling1d_5 (MaxPoolin  (None, 4, 64)             0
#  g1D)
#
#  dropout_5 (Dropout)         (None, 4, 64)             0
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 100)               25700
#
#  dense_16 (Dense)            (None, 50)                5050
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 49681 (194.07 KB)
# Trainable params: 49681 (194.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 39.
# Epoch 49: early stopping
# 26/26 [==============================] - 0s 601us/step
#
# 6) RMSE: 0.017548, Std Dev: 0.030739, Difference: -0.013192
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 7) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 9, 128)            2432
#
#  conv1d_13 (Conv1D)          (None, 8, 64)             16448
#
#  max_pooling1d_6 (MaxPoolin  (None, 4, 64)             0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 4, 64)             0
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 200)               51400
#
#  dense_19 (Dense)            (None, 100)               20100
#
#  dense_20 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 90481 (353.44 KB)
# Trainable params: 90481 (353.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 28.
# Epoch 38: early stopping
# 26/26 [==============================] - 0s 570us/step
#
# 7) RMSE: 0.018120, Std Dev: 0.030739, Difference: -0.012620
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 8) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 9, 128)            2432
#
#  conv1d_15 (Conv1D)          (None, 8, 64)             16448
#
#  max_pooling1d_7 (MaxPoolin  (None, 4, 64)             0
#  g1D)
#
#  dropout_7 (Dropout)         (None, 4, 64)             0
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  dense_21 (Dense)            (None, 200)               51400
#
#  dense_22 (Dense)            (None, 100)               20100
#
#  dense_23 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 90481 (353.44 KB)
# Trainable params: 90481 (353.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 20.
# Epoch 30: early stopping
# 26/26 [==============================] - 0s 595us/step
#
# 8) RMSE: 0.017383, Std Dev: 0.030739, Difference: -0.013356
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 9) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_17 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_8 (MaxPoolin  (None, 6, 64)             0
#  g1D)
#
#  dropout_8 (Dropout)         (None, 6, 64)             0
#
#  flatten_8 (Flatten)         (None, 384)               0
#
#  dense_24 (Dense)            (None, 100)               38500
#
#  dense_25 (Dense)            (None, 50)                5050
#
#  dense_26 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71825 (280.57 KB)
# Trainable params: 71825 (280.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 31.
# Epoch 41: early stopping
# 26/26 [==============================] - 1s 14ms/step
#
# 9) RMSE: 0.018000, Std Dev: 0.030739, Difference: -0.012739
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 10) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_19 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_9 (MaxPoolin  (None, 6, 64)             0
#  g1D)
#
#  dropout_9 (Dropout)         (None, 6, 64)             0
#
#  flatten_9 (Flatten)         (None, 384)               0
#
#  dense_27 (Dense)            (None, 100)               38500
#
#  dense_28 (Dense)            (None, 50)                5050
#
#  dense_29 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71825 (280.57 KB)
# Trainable params: 71825 (280.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 27.
# Epoch 37: early stopping
# 26/26 [==============================] - 0s 618us/step
#
# 10) RMSE: 0.016593, Std Dev: 0.030739, Difference: -0.014146
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 11) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_21 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_10 (MaxPooli  (None, 6, 64)             0
#  ng1D)
#
#  dropout_10 (Dropout)        (None, 6, 64)             0
#
#  flatten_10 (Flatten)        (None, 384)               0
#
#  dense_30 (Dense)            (None, 200)               77000
#
#  dense_31 (Dense)            (None, 100)               20100
#
#  dense_32 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 125425 (489.94 KB)
# Trainable params: 125425 (489.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 28.
# Epoch 38: early stopping
# 26/26 [==============================] - 0s 546us/step
#
# 11) RMSE: 0.018328, Std Dev: 0.030739, Difference: -0.012411
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 12) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_22 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_23 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_11 (MaxPooli  (None, 6, 64)             0
#  ng1D)
#
#  dropout_11 (Dropout)        (None, 6, 64)             0
#
#  flatten_11 (Flatten)        (None, 384)               0
#
#  dense_33 (Dense)            (None, 200)               77000
#
#  dense_34 (Dense)            (None, 100)               20100
#
#  dense_35 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 125425 (489.94 KB)
# Trainable params: 125425 (489.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 48.
# Epoch 58: early stopping
# 26/26 [==============================] - 0s 680us/step
#
# 12) RMSE: 0.017691, Std Dev: 0.030739, Difference: -0.013048
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 13) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_24 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_25 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_12 (MaxPooli  (None, 3, 64)             0
#  ng1D)
#
#  dropout_12 (Dropout)        (None, 3, 64)             0
#
#  flatten_12 (Flatten)        (None, 192)               0
#
#  dense_36 (Dense)            (None, 100)               19300
#
#  dense_37 (Dense)            (None, 50)                5050
#
#  dense_38 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 52625 (205.57 KB)
# Trainable params: 52625 (205.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 19.
# Epoch 29: early stopping
# 26/26 [==============================] - 0s 556us/step
#
# 13) RMSE: 0.018788, Std Dev: 0.030739, Difference: -0.011951
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 14) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_26 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_27 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_13 (MaxPooli  (None, 3, 64)             0
#  ng1D)
#
#  dropout_13 (Dropout)        (None, 3, 64)             0
#
#  flatten_13 (Flatten)        (None, 192)               0
#
#  dense_39 (Dense)            (None, 100)               19300
#
#  dense_40 (Dense)            (None, 50)                5050
#
#  dense_41 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 52625 (205.57 KB)
# Trainable params: 52625 (205.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 21.
# Epoch 31: early stopping
# 26/26 [==============================] - 0s 637us/step
#
# 14) RMSE: 0.017678, Std Dev: 0.030739, Difference: -0.013062
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 15) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_28 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_29 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_14 (MaxPooli  (None, 3, 64)             0
#  ng1D)
#
#  dropout_14 (Dropout)        (None, 3, 64)             0
#
#  flatten_14 (Flatten)        (None, 192)               0
#
#  dense_42 (Dense)            (None, 200)               38600
#
#  dense_43 (Dense)            (None, 100)               20100
#
#  dense_44 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 87025 (339.94 KB)
# Trainable params: 87025 (339.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 20.
# Epoch 30: early stopping
# 26/26 [==============================] - 0s 616us/step
#
# 15) RMSE: 0.019354, Std Dev: 0.030739, Difference: -0.011386
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 16) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_30 (Conv1D)          (None, 8, 128)            3584
#
#  conv1d_31 (Conv1D)          (None, 6, 64)             24640
#
#  max_pooling1d_15 (MaxPooli  (None, 3, 64)             0
#  ng1D)
#
#  dropout_15 (Dropout)        (None, 3, 64)             0
#
#  flatten_15 (Flatten)        (None, 192)               0
#
#  dense_45 (Dense)            (None, 200)               38600
#
#  dense_46 (Dense)            (None, 100)               20100
#
#  dense_47 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 87025 (339.94 KB)
# Trainable params: 87025 (339.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 17.
# Epoch 27: early stopping
# 26/26 [==============================] - 0s 622us/step
#
# 16) RMSE: 0.019365, Std Dev: 0.030739, Difference: -0.011375
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 3, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 17) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_32 (Conv1D)          (None, 6, 128)            5888
#
#  conv1d_33 (Conv1D)          (None, 2, 64)             41024
#
#  max_pooling1d_16 (MaxPooli  (None, 2, 64)             0
#  ng1D)
#
#  dropout_16 (Dropout)        (None, 2, 64)             0
#
#  flatten_16 (Flatten)        (None, 128)               0
#
#  dense_48 (Dense)            (None, 100)               12900
#
#  dense_49 (Dense)            (None, 50)                5050
#
#  dense_50 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 64913 (253.57 KB)
# Trainable params: 64913 (253.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 25.
# Epoch 35: early stopping
# 26/26 [==============================] - 1s 13ms/step
#
# 17) RMSE: 0.018749, Std Dev: 0.030739, Difference: -0.011991
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 18) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_34 (Conv1D)          (None, 6, 128)            5888
#
#  conv1d_35 (Conv1D)          (None, 2, 64)             41024
#
#  max_pooling1d_17 (MaxPooli  (None, 2, 64)             0
#  ng1D)
#
#  dropout_17 (Dropout)        (None, 2, 64)             0
#
#  flatten_17 (Flatten)        (None, 128)               0
#
#  dense_51 (Dense)            (None, 100)               12900
#
#  dense_52 (Dense)            (None, 50)                5050
#
#  dense_53 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 64913 (253.57 KB)
# Trainable params: 64913 (253.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 26.
# Epoch 36: early stopping
# 26/26 [==============================] - 0s 651us/step
#
# 18) RMSE: 0.017653, Std Dev: 0.030739, Difference: -0.013086
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 19) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_36 (Conv1D)          (None, 6, 128)            5888
#
#  conv1d_37 (Conv1D)          (None, 2, 64)             41024
#
#  max_pooling1d_18 (MaxPooli  (None, 2, 64)             0
#  ng1D)
#
#  dropout_18 (Dropout)        (None, 2, 64)             0
#
#  flatten_18 (Flatten)        (None, 128)               0
#
#  dense_54 (Dense)            (None, 200)               25800
#
#  dense_55 (Dense)            (None, 100)               20100
#
#  dense_56 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 92913 (362.94 KB)
# Trainable params: 92913 (362.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 44.
# Epoch 54: early stopping
# 26/26 [==============================] - 0s 651us/step
#
# 19) RMSE: 0.017886, Std Dev: 0.030739, Difference: -0.012854
# Tested with n_steps=10, batch_size=8, epochs=100, filters=64
# Model params: {'filters': 64, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 20) Testing with n_steps=10, batch_size=8, epochs=100, filters=64
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_38 (Conv1D)          (None, 6, 128)            5888
#
#  conv1d_39 (Conv1D)          (None, 2, 64)             41024
#
#  max_pooling1d_19 (MaxPooli  (None, 2, 64)             0
#  ng1D)
#
#  dropout_19 (Dropout)        (None, 2, 64)             0
#
#  flatten_19 (Flatten)        (None, 128)               0
#
#  dense_57 (Dense)            (None, 200)               25800
#
#  dense_58 (Dense)            (None, 100)               20100
#
#  dense_59 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 92913 (362.94 KB)
# Trainable params: 92913 (362.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ...
# =================================================================
# Total params: 718545 (2.74 MB)
# Trainable params: 718545 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 56.
# Epoch 66: early stopping
# 26/26 [==============================] - 0s 882us/step
#
# 569) RMSE: 0.018681, Std Dev: 0.030616, Difference: -0.011935
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 570) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_569"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1138 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1139 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_569 (MaxPool  (None, 42, 128)           0
#  ing1D)
#
#  dropout_569 (Dropout)       (None, 42, 128)           0
#
#  flatten_569 (Flatten)       (None, 5376)              0
#
#  dense_1707 (Dense)          (None, 100)               537700
#
#  dense_1708 (Dense)          (None, 50)                5050
#
#  dense_1709 (Dense)          (None, 1)                 51
#
# =================================================================
# Total params: 718545 (2.74 MB)
# Trainable params: 718545 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 64.
# Epoch 74: early stopping
# 26/26 [==============================] - 0s 925us/step
#
# 570) RMSE: 0.018537, Std Dev: 0.030616, Difference: -0.012079
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 571) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_570"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1140 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1141 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_570 (MaxPool  (None, 42, 128)           0
#  ing1D)
#
#  dropout_570 (Dropout)       (None, 42, 128)           0
#
#  flatten_570 (Flatten)       (None, 5376)              0
#
#  dense_1710 (Dense)          (None, 200)               1075400
#
#  dense_1711 (Dense)          (None, 100)               20100
#
#  dense_1712 (Dense)          (None, 1)                 101
#
# =================================================================
# Total params: 1271345 (4.85 MB)
# Trainable params: 1271345 (4.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 26/26 [==============================] - 0s 1ms/step
#
# 571) RMSE: 0.018368, Std Dev: 0.030616, Difference: -0.012248
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 572) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_571"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1142 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1143 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_571 (MaxPool  (None, 42, 128)           0
#  ing1D)
#
#  dropout_571 (Dropout)       (None, 42, 128)           0
#
#  flatten_571 (Flatten)       (None, 5376)              0
#
#  dense_1713 (Dense)          (None, 200)               1075400
#
#  dense_1714 (Dense)          (None, 100)               20100
#
#  dense_1715 (Dense)          (None, 1)                 101
#
# =================================================================
# Total params: 1271345 (4.85 MB)
# Trainable params: 1271345 (4.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 52.
# Epoch 62: early stopping
# 26/26 [==============================] - 0s 1ms/step
#
# 572) RMSE: 0.018455, Std Dev: 0.030616, Difference: -0.012161
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 573) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_572"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1144 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1145 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_572 (MaxPool  (None, 21, 128)           0
#  ing1D)
#
#  dropout_572 (Dropout)       (None, 21, 128)           0
#
#  flatten_572 (Flatten)       (None, 2688)              0
#
#  dense_1716 (Dense)          (None, 100)               268900
#
#  dense_1717 (Dense)          (None, 50)                5050
#
#  dense_1718 (Dense)          (None, 1)                 51
#
# =================================================================
# Total params: 449745 (1.72 MB)
# Trainable params: 449745 (1.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 45.
# Epoch 55: early stopping
# 26/26 [==============================] - 0s 998us/step
#
# 573) RMSE: 0.022534, Std Dev: 0.030616, Difference: -0.008082
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 574) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_573"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1146 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1147 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_573 (MaxPool  (None, 21, 128)           0
#  ing1D)
#
#  dropout_573 (Dropout)       (None, 21, 128)           0
#
#  flatten_573 (Flatten)       (None, 2688)              0
#
#  dense_1719 (Dense)          (None, 100)               268900
#
#  dense_1720 (Dense)          (None, 50)                5050
#
#  dense_1721 (Dense)          (None, 1)                 51
#
# =================================================================
# Total params: 449745 (1.72 MB)
# Trainable params: 449745 (1.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 76.
# Epoch 86: early stopping
# 26/26 [==============================] - 0s 764us/step
#
# 574) RMSE: 0.020060, Std Dev: 0.030616, Difference: -0.010556
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
#
# 575) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_574"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1148 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1149 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_574 (MaxPool  (None, 21, 128)           0
#  ing1D)
#
#  dropout_574 (Dropout)       (None, 21, 128)           0
#
#  flatten_574 (Flatten)       (None, 2688)              0
#
#  dense_1722 (Dense)          (None, 200)               537800
#
#  dense_1723 (Dense)          (None, 100)               20100
#
#  dense_1724 (Dense)          (None, 1)                 101
#
# =================================================================
# Total params: 733745 (2.80 MB)
# Trainable params: 733745 (2.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 66.
# Epoch 76: early stopping
# 26/26 [==============================] - 0s 910us/step
#
# 575) RMSE: 0.019777, Std Dev: 0.030616, Difference: -0.010839
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 576) Testing with n_steps=50, batch_size=32, epochs=100, filters=128
# Features utilizados: Index(['LMCADS03', 'LMCADY', 'DXY', 'SPX', 'BCOM', 'MXWD', 'XAU', 'XAG',
#        'ACU_5D'],
#       dtype='object')
# Model: "sequential_575"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1150 (Conv1D)        (None, 46, 256)           11776
#
#  conv1d_1151 (Conv1D)        (None, 42, 128)           163968
#
#  max_pooling1d_575 (MaxPool  (None, 21, 128)           0
#  ing1D)
#
#  dropout_575 (Dropout)       (None, 21, 128)           0
#
#  flatten_575 (Flatten)       (None, 2688)              0
#
#  dense_1725 (Dense)          (None, 200)               537800
#
#  dense_1726 (Dense)          (None, 100)               20100
#
#  dense_1727 (Dense)          (None, 1)                 101
#
# =================================================================
# Total params: 733745 (2.80 MB)
# Trainable params: 733745 (2.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 45.
# Epoch 55: early stopping
# 26/26 [==============================] - 0s 844us/step
#
# 576) RMSE: 0.019889, Std Dev: 0.030616, Difference: -0.010727
# Tested with n_steps=50, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 5, 'pool_size': 2, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}

# %%
for i, result in enumerate(top_3_results, 1):
    rmse            = result['rmse']
    model_params    = result['params']
    history         = result['history']
    batch_size      = result['batch_size']
    n_steps         = result['n_steps']
    y_test          = result['actuals']
    y_pred          = result['predictions']
    diff = result['difference']

    print(f"\nTop {i} Model")
    print(f"Best RMSE: {rmse:.6f} vs. a std of {y_test.std():.6f}, diff = {diff:.6f}")
    print(f"Model parameters: {model_params}")
    print(f"n_steps: {n_steps}, batch_size: {batch_size}")

    # plot_history(history)

    plot_predictions(y_test, y_pred, 100, title=f"Top {i} Model Predictions vs Actual")
    # plot_predictions(y_test, y_pred*-1, 100, title=f"Top {i} Model Predictions vs Actual")

    # print the values of predictions and actuals one next to the other(only the first 10)
    # for pred, actual in zip(y_pred[:10], y_test[:10]):
    #     print(f"Predicted: {pred[0]:.6f}, Actual: {actual:.6f}")
# Out:
# Top 1 Model
# Best RMSE: 0.016102 vs. a std of 0.030736, diff = -0.014633
# Model parameters: {'filters': 128, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 16
# Top 2 Model
# Best RMSE: 0.016160 vs. a std of 0.030736, diff = -0.014576
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 16
# Top 3 Model
# Best RMSE: 0.016220 vs. a std of 0.030739, diff = -0.014519
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 10, batch_size: 8
# Top 4 Model
# Best RMSE: 0.016237 vs. a std of 0.030739, diff = -0.014503
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 10, batch_size: 16
# Top 5 Model
# Best RMSE: 0.016214 vs. a std of 0.030616, diff = -0.014402
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 50, batch_size: 16
# Top 6 Model
# Best RMSE: 0.016352 vs. a std of 0.030739, diff = -0.014387
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 10, batch_size: 8
# Top 7 Model
# Best RMSE: 0.016377 vs. a std of 0.030739, diff = -0.014362
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 2, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 10, batch_size: 8
# Top 8 Model
# Best RMSE: 0.016432 vs. a std of 0.030758, diff = -0.014325
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 100, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 20, batch_size: 16
# Top 9 Model
# Best RMSE: 0.016418 vs. a std of 0.030736, diff = -0.014318
# Model parameters: {'filters': 128, 'kernel_size': 3, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 8
# Top 10 Model
# Best RMSE: 0.016423 vs. a std of 0.030736, diff = -0.014313
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.2}
# n_steps: 30, batch_size: 16

# %%
"""
n_steps_options     = [15]
batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64, 128, 256]
kernel_size_options     = [2, 3, 5]
pool_size_options       = [1, 2]
dense_units_options     = [50, 100, 150]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1, 0.2, 0.3]
"""
# Out:
# "\nn_steps_options     = [15]\nbatch_size_options  = [16]\nepochs_options      = [100]\n\nfilters_options         = [64, 128, 256]\nkernel_size_options     = [2, 3, 5]\npool_size_options       = [1, 2]\ndense_units_options     = [50, 100, 150]\n# dense_activation_options = ['relu', 'tanh']\ndense_activation_options = ['relu']\n# activation_options      = ['relu', 'tanh']\nactivation_options      = ['relu']\ndropout_options         = [0.1, 0.2, 0.3]\n"
