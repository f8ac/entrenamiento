# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import itertools
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-05-08 17:44:00.901540: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-08 17:44:00.921990: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 17:44:00.922005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 17:44:00.922558: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 17:44:00.926091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-08 17:44:01.283565: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### 1. Carga de datos

# %%
def load_data(filepath):
    return pd.read_csv(filepath, parse_dates=['Date'])

# %% [markdown]
# ### 2. Division y tratamiento de datos

# %%
def create_sequences(data, target, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:(i + n_steps)])
        y.append(target[i + n_steps])
    return np.array(X), np.array(y)

# %%
def prepare_data(df, target_column, n_steps):
    features = df.drop(columns=[target_column, 'LMCADY_std_5d_log'])

    # agregar dia mes y dia de la semana
    # features['Month'] = df['Date'].dt.month
    # features['Day'] = df['Date'].dt.day
    # features['Weekday'] = df['Date'].dt.weekday

    features = features.drop(columns = ['Date'])

    target = df[target_column]

    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    X, y = create_sequences(features_scaled, target, n_steps)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle = False)

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### 3. Arquitectura y compilacion

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
def build_model(input_shape, md_prm: dict):
    model = Sequential([
        Conv1D(filters=md_prm['filters']*2, kernel_size=md_prm['kernel_size'], activation=md_prm['activation'], input_shape=input_shape),
        Conv1D(filters=md_prm['filters'], kernel_size=md_prm['kernel_size'], activation=md_prm['activation']),
        MaxPooling1D(pool_size=md_prm['pool_size']),
        Dropout(md_prm['dropout']/2),
        Flatten(),
        Dense(md_prm['dense_units']*2, activation=md_prm['dense_activation']),
        Dense(md_prm['dense_units'], activation=md_prm['dense_activation']),
        Dense(1, activation = "linear")
    ])
    # puede ser 0.0005
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=[rmse])
    return model

# %% [markdown]
# ### 4. Entrenamiento del modelo

# %%
def train_model(model, X_train, y_train, epochs, batch_size, verbose):
    early_stopping = EarlyStopping(
        monitor             ='val_rmse',
        patience            =15,
        verbose             =1,
        restore_best_weights=True
    )
    history = model.fit(
        X_train, y_train,
        epochs          =epochs,
        batch_size      =batch_size,
        verbose         =verbose,
        validation_split=0.1,
        callbacks       =[early_stopping]
    )
    return history

# %% [markdown]
# ### 5. Evaluacion de resultado

# %%
def evaluate_model(model, X_test, y_test):
    loss = model.evaluate(X_test, y_test)
    print(f'Test Loss: {loss}')

# %%
def plot_history(history):
    # plotear loss de entrenamiento y validación
    figsize = (8,2)

    plt.figure(figsize=figsize)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    # otras metricas
    for key in history.history.keys():
        if key not in ['loss', 'val_loss', 'val_rmse']:
            plt.figure(figsize=figsize)
            plt.plot(history.history[key], label=f'Training {key}')
            plt.plot(history.history[f'val_{key}'], label=f'Validation {key}')
            plt.title(f'Model {key.capitalize()}')
            plt.ylabel(key.capitalize())
            plt.xlabel('Epoch')
            plt.legend()
            plt.grid(True)
            plt.show()

# %%
def plot_predictions(y_true, y_pred, n, title="Prediction vs Actual Data"):
    # Asegurarse de que n no sea mayor que el número de puntos disponibles
    n = min(n, len(y_true), len(y_pred))

    # Usar slicing para obtener los últimos n valores
    y_true = y_true[-n:]
    y_pred = y_pred[-n:]

    plt.figure(figsize=(12, 2))
    plt.plot(y_true, label='Actual Values', marker='o', linestyle='-')
    plt.plot(y_pred, label='Predicted Values', marker='x', linestyle='--')

    plt.title(title)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# df = load_data("./input/copper_log_returns_5d_final.csv")
# n_steps = 25
# target_column = 'LMCADY_acu_5d_log'
# X_train, X_test, y_train, y_test = prepare_data(df, target_column, n_steps)
# y_test.std()
# model = build_model(X_train.shape[1:])
# history = train_model(model, X_train, y_train, epochs=100, batch_size=16)
# evaluate_model(model, X_test, y_test)

# %%
# n_steps_options     = [25, 50, 100, 150, 200]
# batch_size_options  = [32, 64, 128, 256]
n_steps_options = [10, 20, 30, 50, 100]
batch_size_options = [8, 16, 32]
# n_steps_options     = [15]
# batch_size_options  = [16]
epochs_options      = [100]

filters_options     = [128]
kernel_size_options = [2]
pool_size_options   = [1]
dense_units_options = [50]
dense_activation_options = ['relu']
activation_options  = ['relu']
dropout_options     = [0.1]


model_params_combinations = list(itertools.product(
    filters_options, kernel_size_options, pool_size_options, dense_units_options,
    dense_activation_options, activation_options, dropout_options
))
target_column = 'LMCADY_acu_5d_log'

# %%
# number of iterations
n_iter = len(n_steps_options) * len(batch_size_options) * len(epochs_options) * len(model_params_combinations)
print(f'Total iterations: {n_iter}')
# Out:
# Total iterations: 15

# %%
def run_model_iterations():
    top_results = []

    i = 1
    for n_steps, batch_size, epochs, (filters, kernel_size, pool_size, dense_units, dense_activation, activation, dropout) in itertools.product(n_steps_options, batch_size_options, epochs_options, model_params_combinations):
        try:
            # Carga de datos
            df = load_data("./input/copper_log_returns_5d_final.csv")
            print(f"\n{i}) Testing with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")

            # Preparación de los datos
            X_train, X_test, y_train, y_test = prepare_data(df, 'LMCADY_acu_5d_log', n_steps)

            # print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}, y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

            # show a sample of X_train
            # print(f"X_train[1]: {X_train[1]}")
            # print("X_train[1] shape: ", X_train[1].shape)
            # print("X_train[2]: ", X_train[2])
            # print("X_train[2] shape: ", X_train[2].shape)
            # print("X_train",X_train)
            # print("X_train shape: ", X_train.shape)

            # Configuración de parámetros del modelo
            model_params = {
                'filters'           : filters,
                'kernel_size'       : kernel_size,
                'pool_size'         : pool_size,
                'dense_units'       : dense_units,
                'dense_activation'  : dense_activation,
                'activation'        : activation,
                'dropout'           : dropout
            }

            # Construcción y entrenamiento del modelo
            model   = build_model(X_train.shape[1:], model_params)
            print(model.summary())
            history = train_model(model, X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

            # Evaluación del modelo
            y_pred  = model.predict(X_test)
            # y_pred *= -1
            rmse_ob = sqrt(mean_squared_error(y_test, y_pred))
            std_dev = y_test.std()

            # diferencia entre rmse y desvstd
            difference = rmse_ob - std_dev

            # Guardar y ordenar resultados basados en la diferencia absoluta
            result = {
                'difference': difference,
                'rmse'      : rmse_ob,
                'std_dev'   : std_dev,
                'params'    : model_params,
                'history'   : history,
                'batch_size': batch_size,
                'n_steps'   : n_steps,
                'predictions': y_pred,
                'actuals'   : y_test
            }
            top_results.append(result)
            top_results = sorted(top_results, key=lambda x: x['difference'])#[:5]

            print(f"\n{i}) RMSE: {rmse_ob:.6f}, Std Dev: {std_dev:.6f}, Difference: {difference:.6f}")
            print(f"Tested with n_steps={n_steps}, batch_size={batch_size}, epochs={epochs}, filters={filters}")
            print(f"Model params: {model_params}")

        except Exception as e:
            print(f"An error occurred: {e}. Skipping this combination.")
        i += 1

    return top_results

# %%
top_3_results = run_model_iterations()
# Out:
# 1) Testing with n_steps=10, batch_size=8, epochs=100, filters=128
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 9, 256)            4352
#
#  conv1d_1 (Conv1D)           (None, 8, 128)            65664
#
#  max_pooling1d (MaxPooling1  (None, 8, 128)            0
#  D)
#
#  dropout (Dropout)           (None, 8, 128)            0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 100)               102500
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 177617 (693.82 KB)
# Trainable params: 177617 (693.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 2024-05-08 17:44:01.966861: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:01.986182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:01.986350: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:01.987423: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:01.987505: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:01.987556: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:02.610899: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:02.611004: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:02.611061: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-08 17:44:02.611107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7992 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-05-08 17:44:04.109081: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-05-08 17:44:04.582872: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-08 17:44:04.777962: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-08 17:44:05.473015: I external/local_xla/xla/service/service.cc:168] XLA service 0x5ba45e4bdb60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-08 17:44:05.473029: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-05-08 17:44:05.476214: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715208245.530000  309469 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 530/530 [==============================] - 6s 4ms/step - loss: 0.0030 - rmse: 0.0493 - val_loss: 0.0015 - val_rmse: 0.0325
# Epoch 2/100
# 530/530 [==============================] - 1s 1ms/step - loss: 0.0015 - rmse: 0.0370 - val_loss: 9.6144e-04 - val_rmse: 0.0270
# Epoch 3/100
# 530/530 [==============================] - 1s 1ms/step - loss: 0.0012 - rmse: 0.0336 - val_loss: 9.9087e-04 - val_rmse: 0.0271
# Epoch 4/100
# 530/530 [==============================] - 1s 1ms/step - loss: 0.0011 - rmse: 0.0320 - val_loss: 8.9009e-04 - val_rmse: 0.0258
# Epoch 5/100
# 530/530 [==============================] - 1s 1ms/step - loss: 0.0010 - rmse: 0.0306 - val_loss: 8.7617e-04 - val_rmse: 0.0257
# Epoch 6/100
# 530/530 [==============================] - 1s 2ms/step - loss: 9.5187e-04 - rmse: 0.0294 - val_loss: 9.3669e-04 - val_rmse: 0.0259
# Epoch 7/100
# 530/530 [==============================] - 1s 1ms/step - loss: 8.7159e-04 - rmse: 0.0283 - val_loss: 8.8339e-04 - val_rmse: 0.0258
# Epoch 8/100
# 530/530 [==============================] - 1s 1ms/step - loss: 8.3214e-04 - rmse: 0.0275 - val_loss: 9.2954e-04 - val_rmse: 0.0261
# Epoch 9/100
# 530/530 [==============================] - 1s 1ms/step - loss: 7.5484e-04 - rmse: 0.0264 - val_loss: 9.0105e-04 - val_rmse: 0.0257
# Epoch 10/100
# 530/530 [==============================] - 1s 1ms/step - loss: 7.1866e-04 - rmse: 0.0257 - val_loss: 9.7598e-04 - val_rmse: 0.0268
# Epoch 11/100
# 530/530 [==============================] - 1s 1ms/step - loss: 6.2028e-04 - rmse: 0.0237 - val_loss: 9.8194e-04 - val_rmse: 0.0275
# Epoch 12/100
# 530/530 [==============================] - 1s 1ms/step - loss: 5.9612e-04 - rmse: 0.0234 - val_loss: 9.4661e-04 - val_rmse: 0.0269
# Epoch 13/100
# 530/530 [==============================] - 1s 1ms/step - loss: 5.2733e-04 - rmse: 0.0221 - val_loss: 0.0010 - val_rmse: 0.0272
# Epoch 14/100
# 530/530 [==============================] - 1s 1ms/step - loss: 4.9417e-04 - rmse: 0.0212 - val_loss: 9.1978e-04 - val_rmse: 0.0264
# Epoch 15/100
# 530/530 [==============================] - 1s 1ms/step - loss: 4.9774e-04 - rmse: 0.0211 - val_loss: 0.0011 - val_rmse: 0.0273
# Epoch 16/100
# 530/530 [==============================] - 1s 1ms/step - loss: 4.3094e-04 - rmse: 0.0198 - val_loss: 9.8895e-04 - val_rmse: 0.0269
# Epoch 17/100
# 530/530 [==============================] - 1s 1ms/step - loss: 4.1273e-04 - rmse: 0.0193 - val_loss: 0.0011 - val_rmse: 0.0283
# Epoch 18/100
# 530/530 [==============================] - 1s 1ms/step - loss: 3.7178e-04 - rmse: 0.0183 - val_loss: 0.0011 - val_rmse: 0.0279
# Epoch 19/100
# 530/530 [==============================] - 1s 2ms/step - loss: 3.5120e-04 - rmse: 0.0178 - val_loss: 0.0011 - val_rmse: 0.0286
# Epoch 20/100
# 530/530 [==============================] - 1s 1ms/step - loss: 3.0549e-04 - rmse: 0.0167 - val_loss: 0.0011 - val_rmse: 0.0287
# Epoch 21/100
# 530/530 [==============================] - 1s 1ms/step - loss: 3.0197e-04 - rmse: 0.0165 - val_loss: 0.0010 - val_rmse: 0.0277
# Epoch 22/100
# 530/530 [==============================] - 1s 1ms/step - loss: 3.0545e-04 - rmse: 0.0164 - val_loss: 0.0011 - val_rmse: 0.0283
# Epoch 23/100
# 530/530 [==============================] - 1s 2ms/step - loss: 2.5980e-04 - rmse: 0.0152 - val_loss: 0.0011 - val_rmse: 0.0283
# Epoch 24/100
# 503/530 [===========================>..] - ETA: 0s - loss: 2.6531e-04 - rmse: 0.0154Restoring model weights from the end of the best epoch: 9.
# 530/530 [==============================] - 1s 1ms/step - loss: 2.6518e-04 - rmse: 0.0154 - val_loss: 0.0011 - val_rmse: 0.0282
# Epoch 24: early stopping
# 26/26 [==============================] - 1s 16ms/step
#
# 1) RMSE: 0.033789, Std Dev: 0.030667, Difference: 0.003122
# Tested with n_steps=10, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 2) Testing with n_steps=10, batch_size=16, epochs=100, filters=128
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 9, 256)            4352
#
#  conv1d_3 (Conv1D)           (None, 8, 128)            65664
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 128)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 8, 128)            0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 100)               102500
#
#  dense_4 (Dense)             (None, 50)                5050
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 177617 (693.82 KB)
# Trainable params: 177617 (693.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 265/265 [==============================] - 3s 6ms/step - loss: 0.0034 - rmse: 0.0544 - val_loss: 0.0015 - val_rmse: 0.0354
# Epoch 2/100
# 265/265 [==============================] - 0s 2ms/step - loss: 0.0017 - rmse: 0.0397 - val_loss: 0.0013 - val_rmse: 0.0316
# Epoch 3/100
# 265/265 [==============================] - 0s 2ms/step - loss: 0.0014 - rmse: 0.0359 - val_loss: 0.0012 - val_rmse: 0.0304
epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 3) Testing with n_steps=10, batch_size=32, epochs=100, filters=128
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 9, 256)            4352
#
#  conv1d_5 (Conv1D)           (None, 8, 128)            65664
#
#  max_pooling1d_2 (MaxPoolin  (None, 8, 128)            0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 8, 128)            0
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 100)               102500
#
#  dense_7 (Dense)             (None, 50)                5050
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 177617 (693.82 KB)
# Trainable params: 177617 (693.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 133/133 [==============================] - 2s 5ms/step - loss: 0.0039 - rmse: 0.0586 - val_loss: 0.0016 - val_rmse: 0.0359
# Epoch 2/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0018 - rmse: 0.0412 - val_loss: 0.0014 - val_rmse: 0.0331
# Epoch 3/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0014 - rmse: 0.0376 - val_loss: 0.0012 - val_rmse: 0.0316
# Epoch 4/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0013 - rmse: 0.0353 - val_loss: 0.0012 - val_rmse: 0.0308
# Epoch 5/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0012 - rmse: 0.0336 - val_loss: 0.0011 - val_rmse: 0.0306
# Epoch 6/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0011 - rmse: 0.0323 - val_loss: 0.0012 - val_rmse: 0.0306
# Epoch 7/100
# 133/133 [==============================] - 0s 2ms/step - loss: 9.7981e-04 - rmse: 0.0310 - val_loss: 0.0011 - val_rmse: 0.0300
# Epoch 8/100
# 133/133 [==============================] - 0s 2ms/step - loss: 9.3467e-04 - rmse: 0.0303 - val_loss: 0.0011 - val_rmse: 0.0305
# Epoch 9/100
# 133/133 [==============================] - 0s 2ms/step - loss: 8.7212e-04 - rmse: 0.0292 - val_loss: 0.0011 - val_rmse: 0.0308
# Epoch 10/100
# 133/133 [==============================] - 0s 2ms/step - loss: 8.1491e-04 - rmse: 0.0282 - val_loss: 0.0011 - val_rmse: 0.0304
# Epoch 11/100
# 133/133 [==============================] - 0s 2ms/step - loss: 7.6749e-04 - rmse: 0.0274 - val_loss: 0.0011 - val_rmse: 0.0305
# Epoch 12/100
# 133/133 [==============================] - 0s 2ms/step - loss: 7.2801e-04 - rmse: 0.0267 - val_loss: 0.0011 - val_rmse: 0.0302
# Epoch 13/100
# 133/133 [==============================] - 0s 2ms/step - loss: 6.9427e-04 - rmse: 0.0261 - val_loss: 0.0012 - val_rmse: 0.0308
# Epoch 14/100
# 133/133 [==============================] - 0s 2ms/step - loss: 6.5429e-04 - rmse: 0.0254 - val_loss: 0.0012 - val_rmse: 0.0311
# Epoch 15/100
# 133/133 [==============================] - 0s 2ms/step - loss: 6.0600e-04 - rmse: 0.0243 - val_loss: 0.0012 - val_rmse: 0.0307
# Epoch 16/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.8649e-04 - rmse: 0.0239 - val_loss: 0.0012 - val_rmse: 0.0307
# Epoch 17/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.2992e-04 - rmse: 0.0228 - val_loss: 0.0012 - val_rmse: 0.0309
# Epoch 18/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.1653e-04 - rmse: 0.0224 - val_loss: 0.0012 - val_rmse: 0.0309
# Epoch 19/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.1384e-04 - rmse: 0.0224 - val_loss: 0.0012 - val_rmse: 0.0309
# Epoch 20/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.6200e-04 - rmse: 0.0212 - val_loss: 0.0012 - val_rmse: 0.0314
# Epoch 21/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.3168e-04 - rmse: 0.0206 - val_loss: 0.0012 - val_rmse: 0.0317
# Epoch 22/100
# 102/133 [======================>.......] - ETA: 0s - loss: 4.1763e-04 - rmse: 0.0202Restoring model weights from the end of the best epoch: 7.
# 133/133 [==============================] - 0s 2ms/step - loss: 4.1493e-04 - rmse: 0.0202 - val_loss: 0.0012 - val_rmse: 0.0314
# Epoch 22: early stopping
# 26/26 [==============================] - 0s 651us/step
#
# 3) RMSE: 0.033207, Std Dev: 0.030667, Difference: 0.002539
# Tested with n_steps=10, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 4) Testing with n_steps=20, batch_size=8, epochs=100, filters=128
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 19, 256)           4352
#
#  conv1d_7 (Conv1D)           (None, 18, 128)           65664
#
#  max_pooling1d_3 (MaxPoolin  (None, 18, 128)           0
#  g1D)
#
#  dropout_3 (Dropout)         (None, 18, 128)           0
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_9 (Dense)             (None, 100)               230500
#
#  dense_10 (Dense)            (None, 50)                5050
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 305617 (1.17 MB)
# Trainable params: 305617 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 529/529 [==============================] - 4s 5ms/step - loss: 0.0030 - rmse: 0.0494 - val_loss: 0.0012 - val_rmse: 0.0306
# Epoch 2/100
# 529/529 [==============================] - 1s 2ms/step - loss: 0.0014 - rmse: 0.0359 - val_loss: 0.0011 - val_rmse: 0.0285
# Epoch 3/100
# 529/529 [==============================] - 1s 2ms/step - loss: 0.0012 - rmse: 0.0331 - val_loss: 9.3153e-04 - val_rmse: 0.0267
# Epoch 4/100
# 529/529 [==============================] - 1s 2ms/step - loss: 0.0011 - rmse: 0.0313 - val_loss: 9.3997e-04 - val_rmse: 0.0269
# Epoch 5/100
# 529/529 [==============================] - 1s 2ms/step - loss: 9.2344e-04 - rmse: 0.0291 - val_loss: 0.0010 - val_rmse: 0.0277
# Epoch 6/100
# 529/529 [==============================] - 1s 2ms/step - loss: 8.5882e-04 - rmse: 0.0281 - val_loss: 0.0010 - val_rmse: 0.0279
# Epoch 7/100
# 529/529 [==============================] - 1s 2ms/step - loss: 7.5685e-04 - rmse: 0.0264 - val_loss: 0.0012 - val_rmse: 0.0297
# Epoch 8/100
# 529/529 [==============================] - 1s 2ms/step - loss: 6.6475e-04 - rmse: 0.0247 - val_loss: 0.0011 - val_rmse: 0.0289
# Epoch 9/100
# 529/529 [==============================] - 1s 2ms/step - loss: 5.9850e-04 - rmse: 0.0233 - val_loss: 0.0010 - val_rmse: 0.0282
# Epoch 10/100
# 529/529 [==============================] - 1s 2ms/step - loss: 5.4340e-04 - rmse: 0.0221 - val_loss: 0.0011 - val_rmse: 0.0293
# Epoch 11/100
# 529/529 [==============================] - 1s 2ms/step - loss: 5.2226e-04 - rmse: 0.0216 - val_loss: 0.0011 - val_rmse: 0.0287
# Epoch 12/100
# 529/529 [==============================] - 1s 2ms/step - loss: 4.5337e-04 - rmse: 0.0198 - val_loss: 0.0011 - val_rmse: 0.0289
# Epoch 13/100
# 529/529 [==============================] - 1s 2ms/step - loss: 3.5439e-04 - rmse: 0.0178 - val_loss: 0.0011 - val_rmse: 0.0289
# Epoch 14/100
# 529/529 [==============================] - 1s 2ms/step - loss: 3.2679e-04 - rmse: 0.0170 - val_loss: 0.0011 - val_rmse: 0.0292
# Epoch 15/100
# 529/529 [==============================] - 1s 2ms/step - loss: 2.9004e-04 - rmse: 0.0161 - val_loss: 0.0012 - val_rmse: 0.0303
# Epoch 16/100
# 529/529 [==============================] - 1s 2ms/step - loss: 2.8952e-04 - rmse: 0.0158 - val_loss: 0.0011 - val_rmse: 0.0289
# Epoch 17/100
# 529/529 [==============================] - 1s 2ms/step - loss: 2.4026e-04 - rmse: 0.0146 - val_loss: 0.0012 - val_rmse: 0.0296
# Epoch 18/100
# 516/529 [============================>.] - ETA: 0s - loss: 2.3131e-04 - rmse: 0.0142Restoring model weights from the end of the best epoch: 3.
# 529/529 [==============================] - 1s 2ms/step - loss: 2.3030e-04 - rmse: 0.0142 - val_loss: 0.0011 - val_rmse: 0.0285
# Epoch 18: early stopping
# 26/26 [==============================] - 1s 12ms/step
#
# 4) RMSE: 0.032154, Std Dev: 0.030634, Difference: 0.001520
# Tested with n_steps=20, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 5) Testing with n_steps=20, batch_size=16, epochs=100, filters=128
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 19, 256)           4352
#
#  conv1d_9 (Conv1D)           (None, 18, 128)           65664
#
#  max_pooling1d_4 (MaxPoolin  (None, 18, 128)           0
#  g1D)
#
#  dropout_4 (Dropout)         (None, 18, 128)           0
#
#  flatten_4 (Flatten)         (None, 2304)              0
#
#  dense_12 (Dense)            (None, 100)               230500
#
#  dense_13 (Dense)            (None, 50)                5050
#
#  dense_14 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 305617 (1.17 MB)
# Trainable params: 305617 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 265/265 [==============================] - 2s 3ms/step - loss: 0.0034 - rmse: 0.0545 - val_loss: 0.0013 - val_rmse: 0.0338
# Epoch 2/100
# 265/265 [==============================] - 1s 2ms/step - loss: 0.0015 - rmse: 0.0376 - val_loss: 9.2267e-04 - val_rmse: 0.0280
# Epoch 3/100
# 265/265 [==============================] - 1s 2ms/step - loss: 0.0012 - rmse: 0.0339 - val_loss: 9.2441e-04 - val_rmse: 0.0285
# Epoch 4/100
# 265/265 [==============================] - 1s 2ms/step - loss: 0.0011 - rmse: 0.0318 - val_loss: 8.4946e-04 - val_rmse: 0.0272
# Epoch 5/100
# 265/265 [==============================] - 1s 2ms/step - loss: 9.8816e-04 - rmse: 0.0307 - val_loss: 8.7380e-04 - val_rmse: 0.0277
# Epoch 6/100
# 265/265 [==============================] - 1s 2ms/step - loss: 8.5292e-04 - rmse: 0.0286 - val_loss: 8.7888e-04 - val_rmse: 0.0277
# Epoch 7/100
# 265/265 [==============================] - 1s 2ms/step - loss: 7.9460e-04 - rmse: 0.0274 - val_loss: 9.5234e-04 - val_rmse: 0.0285
# Epoch 8/100
# 265/265 [==============================] - 1s 2ms/step - loss: 7.4066e-04 - rmse: 0.0265 - val_loss: 9.2798e-04 - val_rmse: 0.0285
# Epoch 9/100
# 265/265 [==============================] - 1s 2ms/step - loss: 6.4112e-04 - rmse: 0.0248 - val_loss: 8.4830e-04 - val_rmse: 0.0275
# Epoch 10/100
# 265/265 [==============================] - 1s 2ms/step - loss: 5.9212e-04 - rmse: 0.0237 - val_loss: 9.1664e-04 - val_rmse: 0.0289
# Epoch 11/100
# 265/265 [==============================] - 1s 2ms/step - loss: 5.6996e-04 - rmse: 0.0232 - val_loss: 0.0010 - val_rmse: 0.0297
# Epoch 12/100
# 265/265 [==============================] - 1s 2ms/step - loss: 5.4965e-04 - rmse: 0.0226 - val_loss: 9.8199e-04 - val_rmse: 0.0290
# Epoch 13/100
# 265/265 [==============================] - 1s 2ms/step - loss: 4.4265e-04 - rmse: 0.0205 - val_loss: 9.9435e-04 - val_rmse: 0.0294
# Epoch 14/100
# 265/265 [==============================] - 1s 2ms/step - loss: 4.0570e-04 - rmse: 0.0196 - val_loss: 9.0576e-04 - val_rmse: 0.0284
# Epoch 15/100
# 265/265 [==============================] - 1s 2ms/step - loss: 4.0939e-04 - rmse: 0.0194 - val_loss: 0.0010 - val_rmse: 0.0291
# Epoch 16/100
# 265/265 [==============================] - 1s 2ms/step - loss: 3.2847e-04 - rmse: 0.0177 - val_loss: 9.8044e-04 - val_rmse: 0.0291
# Epoch 17/100
# 265/265 [==============================] - 1s 2ms/step - loss: 3.7505e-04 - rmse: 0.0187 - val_loss: 8.9629e-04 - val_rmse: 0.0278
# Epoch 18/100
# 265/265 [==============================] - 1s 2ms/step - loss: 4.5590e-04 - rmse: 0.0200 - val_loss: 9.8550e-04 - val_rmse: 0.0288
# Epoch 19/100
# 246/265 [==========================>...] - ETA: 0s - loss: 2.9201e-04 - rmse: 0.0166Restoring model weights from the end of the best epoch: 4.
# 265/265 [==============================] - 1s 2ms/step - loss: 2.9207e-04 - rmse: 0.0166 - val_loss: 9.2490e-04 - val_rmse: 0.0283
# Epoch 19: early stopping
# 26/26 [==============================] - 0s 556us/step
#
# 5) RMSE: 0.033768, Std Dev: 0.030634, Difference: 0.003133
# Tested with n_steps=20, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 6) Testing with n_steps=20, batch_size=32, epochs=100, filters=128
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 19, 256)           4352
#
#  conv1d_11 (Conv1D)          (None, 18, 128)           65664
#
#  max_pooling1d_5 (MaxPoolin  (None, 18, 128)           0
#  g1D)
#
#  dropout_5 (Dropout)         (None, 18, 128)           0
#
#  flatten_5 (Flatten)         (None, 2304)              0
#
#  dense_15 (Dense)            (None, 100)               230500
#
#  dense_16 (Dense)            (None, 50)                5050
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 305617 (1.17 MB)
# Trainable params: 305617 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 133/133 [==============================] - 2s 5ms/step - loss: 0.0035 - rmse: 0.0562 - val_loss: 0.0015 - val_rmse: 0.0354
# Epoch 2/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0016 - rmse: 0.0393 - val_loss: 0.0012 - val_rmse: 0.0312
# Epoch 3/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0013 - rmse: 0.0355 - val_loss: 0.0011 - val_rmse: 0.0303
# Epoch 4/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0011 - rmse: 0.0334 - val_loss: 0.0011 - val_rmse: 0.0306
# Epoch 5/100
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0011 - rmse: 0.0323 - val_loss: 0.0011 - val_rmse: 0.0301
# Epoch 6/100
# 133/133 [==============================] - 0s 2ms/step - loss: 9.8275e-04 - rmse: 0.0310 - val_loss: 0.0012 - val_rmse: 0.0313
# Epoch 7/100
# 133/133 [==============================] - 0s 2ms/step - loss: 8.9637e-04 - rmse: 0.0296 - val_loss: 0.0011 - val_rmse: 0.0306
# Epoch 8/100
# 133/133 [==============================] - 0s 2ms/step - loss: 8.1322e-04 - rmse: 0.0282 - val_loss: 0.0012 - val_rmse: 0.0307
# Epoch 9/100
# 133/133 [==============================] - 0s 2ms/step - loss: 7.6030e-04 - rmse: 0.0273 - val_loss: 0.0012 - val_rmse: 0.0309
# Epoch 10/100
# 133/133 [==============================] - 0s 2ms/step - loss: 7.1170e-04 - rmse: 0.0263 - val_loss: 0.0011 - val_rmse: 0.0303
# Epoch 11/100
# 133/133 [==============================] - 0s 2ms/step - loss: 6.6404e-04 - rmse: 0.0254 - val_loss: 0.0011 - val_rmse: 0.0304
# Epoch 12/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.9681e-04 - rmse: 0.0240 - val_loss: 0.0011 - val_rmse: 0.0308
# Epoch 13/100
# 133/133 [==============================] - 0s 2ms/step - loss: 5.6538e-04 - rmse: 0.0234 - val_loss: 0.0013 - val_rmse: 0.0325
# Epoch 14/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.8689e-04 - rmse: 0.0217 - val_loss: 0.0012 - val_rmse: 0.0313
# Epoch 15/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.6677e-04 - rmse: 0.0214 - val_loss: 0.0012 - val_rmse: 0.0314
# Epoch 16/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.2266e-04 - rmse: 0.0202 - val_loss: 0.0012 - val_rmse: 0.0317
# Epoch 17/100
# 133/133 [==============================] - 0s 2ms/step - loss: 4.1424e-04 - rmse: 0.0200 - val_loss: 0.0011 - val_rmse: 0.0312
# Epoch 18/100
# 133/133 [==============================] - 0s 2ms/step - loss: 3.7134e-04 - rmse: 0.0189 - val_loss: 0.0013 - val_rmse: 0.0326
# Epoch 19/100
# 133/133 [==============================] - 0s 2ms/step - loss: 3.6271e-04 - rmse: 0.0188 - val_loss: 0.0011 - val_rmse: 0.0308
# Epoch 20/100
# 118/133 [=========================>....] - ETA: 0s - loss: 3.3366e-04 - rmse: 0.0175Restoring model weights from the end of the best epoch: 5.
# 133/133 [==============================] - 0s 2ms/step - loss: 3.4119e-04 - rmse: 0.0177 - val_loss: 0.0012 - val_rmse: 0.0315
# Epoch 20: early stopping
# 26/26 [==============================] - 0s 567us/step
#
# 6) RMSE: 0.033882, Std Dev: 0.030634, Difference: 0.003248
# Tested with n_steps=20, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 7) Testing with n_steps=30, batch_size=8, epochs=100, filters=128
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 29, 256)           4352
#
#  conv1d_13 (Conv1D)          (None, 28, 128)           65664
#
#  max_pooling1d_6 (MaxPoolin  (None, 28, 128)           0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 28, 128)           0
#
#  flatten_6 (Flatten)         (None, 3584)              0
#
#  dense_18 (Dense)            (None, 100)               358500
#
#  dense_19 (Dense)            (None, 50)                5050
#
#  dense_20 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 433617 (1.65 MB)
# Trainable params: 433617 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 528/528 [==============================] - 4s 5ms/step - loss: 0.0024 - rmse: 0.0451 - val_loss: 8.8827e-04 - val_rmse: 0.0255
# Epoch 2/100
# 528/528 [==============================] - 1s 2ms/step - loss: 0.0013 - rmse: 0.0347 - val_loss: 0.0011 - val_rmse: 0.0291
# Epoch 3/100
# 528/528 [==============================] - 1s 2ms/step - loss: 0.0011 - rmse: 0.0313 - val_loss: 0.0010 - val_rmse: 0.0271
# Epoch 4/100
# 528/528 [==============================] - 1s 2ms/step - loss: 9.4057e-04 - rmse: 0.0294 - val_loss: 9.9462e-04 - val_rmse: 0.0269
# Epoch 5/100
# 528/528 [==============================] - 1s 2ms/step - loss: 7.7636e-04 - rmse: 0.0268 - val_loss: 9.1662e-04 - val_rmse: 0.0264
# Epoch 6/100
# 528/528 [==============================] - 1s 2ms/step - loss: 6.6478e-04 - rmse: 0.0247 - val_loss: 0.0010 - val_rmse: 0.0276
# Epoch 7/100
# 528/528 [==============================] - 1s 2ms/step - loss: 5.9365e-04 - rmse: 0.0232 - val_loss: 0.0011 - val_rmse: 0.0279
# Epoch 8/100
# 528/528 [==============================] - 1s 2ms/step - loss: 5.6895e-04 - rmse: 0.0220 - val_loss: 0.0011 - val_rmse: 0.0293
# Epoch 9/100
# 528/528 [==============================] - 1s 2ms/step - loss: 4.9016e-04 - rmse: 0.0209 - val_loss: 0.0011 - val_rmse: 0.0279
# Epoch 10/100
# 528/528 [==============================] - 1s 2ms/step - loss: 4.0526e-04 - rmse: 0.0190 - val_loss: 9.2270e-04 - val_rmse: 0.0260
# Epoch 11/100
# 528/528 [==============================] - 1s 2ms/step - loss: 3.4531e-04 - rmse: 0.0174 - val_loss: 0.0011 - val_rmse: 0.0284
# Epoch 12/100
# 528/528 [==============================] - 1s 2ms/step - loss: 3.1777e-04 - rmse: 0.0164 - val_loss: 9.9212e-04 - val_rmse: 0.0271
# Epoch 13/100
# 528/528 [==============================] - 1s 2ms/step - loss: 2.9992e-04 - rmse: 0.0159 - val_loss: 0.0010 - val_rmse: 0.0281
# Epoch 14/100
# 528/528 [==============================] - 1s 2ms/step - loss: 2.2818e-04 - rmse: 0.0140 - val_loss: 0.0010 - val_rmse: 0.0275
# Epoch 15/100
# 528/528 [==============================] - 1s 2ms/step - loss: 2.1024e-04 - rmse: 0.0133 - val_loss: 9.6981e-04 - val_rmse: 0.0270
# Epoch 16/100
# 511/528 [============================>.] - ETA: 0s - loss: 2.0336e-04 - rmse: 0.0131Restoring model weights from the end of the best epoch: 1.
# 528/528 [==============================] - 1s 2ms/step - loss: 2.0353e-04 - rmse: 0.0131 - val_loss: 0.0010 - val_rmse: 0.0277
# Epoch 16: early stopping
# 26/26 [==============================] - 1s 16ms/step
#
# 7) RMSE: 0.033443, Std Dev: 0.030613, Difference: 0.002830
# Tested with n_steps=30, batch_size=8, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 8) Testing with n_steps=30, batch_size=16, epochs=100, filters=128
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 29, 256)           4352
#
#  conv1d_15 (Conv1D)          (None, 28, 128)           65664
#
#  max_pooling1d_7 (MaxPoolin  (None, 28, 128)           0
#  g1D)
#
#  dropout_7 (Dropout)         (None, 28, 128)           0
#
#  flatten_7 (Flatten)         (None, 3584)              0
#
#  dense_21 (Dense)            (None, 100)               358500
#
#  dense_22 (Dense)            (None, 50)                5050
#
#  dense_23 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 433617 (1.65 MB)
# Trainable params: 433617 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 264/264 [==============================] - 4s 8ms/step - loss: 0.0026 - rmse: 0.0465 - val_loss: 0.0011 - val_rmse: 0.0297
# Epoch 2/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.0014 - rmse: 0.0361 - val_loss: 7.9481e-04 - val_rmse: 0.0257
# Epoch 3/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.0012 - rmse: 0.0337 - val_loss: 8.0269e-04 - val_rmse: 0.0258
# Epoch 4/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.0010 - rmse: 0.0312 - val_loss: 7.8594e-04 - val_rmse: 0.0257
# Epoch 5/100
# 264/264 [==============================] - 1s 3ms/step - loss: 8.8351e-04 - rmse: 0.0291 - val_loss: 8.4602e-04 - val_rmse: 0.0264
# Epoch 6/100
# 264/264 [==============================] - 1s 2ms/step - loss: 7.9048e-04 - rmse: 0.0275 - val_loss: 8.5905e-04 - val_rmse: 0.0265
# Epoch 7/100
# 264/264 [==============================] - 1s 3ms/step - loss: 6.9023e-04 - rmse: 0.0256 - val_loss: 8.5808e-04 - val_rmse: 0.0268
# Epoch 8/100
# 264/264 [==============================] - 1s 3ms/step - loss: 6.8855e-04 - rmse: 0.0252 - val_loss: 9.2655e-04 - val_rmse: 0.0275
# Epoch 9/100
# 264/264 [==============================] - 1s 3ms/step - loss: 5.8383e-04 - rmse: 0.0235 - val_loss: 9.2796e-04 - val_rmse: 0.0277
# Epoch 10/100
# 264/264 [==============================] - 1s 3ms/step - loss: 5.2752e-04 - rmse: 0.0224 - val_loss: 9.6659e-04 - val_rmse: 0.0287
# Epoch 11/100
# 264/264 [==============================] - 1s 3ms/step - loss: 4.2436e-04 - rmse: 0.0201 - val_loss: 9.7231e-04 - val_rmse: 0.0284
# Epoch 12/100
# 264/264 [==============================] - 1s 3ms/step - loss: 3.6947e-04 - rmse: 0.0187 - val_loss: 9.0946e-04 - val_rmse: 0.0270
# Epoch 13/100
# 264/264 [==============================] - 1s 3ms/step - loss: 3.3158e-04 - rmse: 0.0177 - val_loss: 0.0011 - val_rmse: 0.0302
# Epoch 14/100
# 264/264 [==============================] - 1s 3ms/step - loss: 3.1391e-04 - rmse: 0.0170 - val_loss: 9.7356e-04 - val_rmse: 0.0285
# Epoch 15/100
# 264/264 [==============================] - 1s 3ms/step - loss: 3.1107e-04 - rmse: 0.0169 - val_loss: 0.0010 - val_rmse: 0.0296
# Epoch 16/100
# 264/264 [==============================] - 1s 3ms/step - loss: 2.9075e-04 - rmse: 0.0164 - val_loss: 0.0010 - val_rmse: 0.0290
# Epoch 17/100
# 261/264 [============================>.] - ETA: 0s - loss: 2.3166e-04 - rmse: 0.0147Restoring model weights from the end of the best epoch: 2.
# 264/264 [==============================] - 1s 2ms/step - loss: 2.3104e-04 - rmse: 0.0147 - val_loss: 0.0011 - val_rmse: 0.0299
# Epoch 17: early stopping
# 26/26 [==============================] - 0s 627us/step
#
# 8) RMSE: 0.033131, Std Dev: 0.030613, Difference: 0.002518
# Tested with n_steps=30, batch_size=16, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
#
# 9) Testing with n_steps=30, batch_size=32, epochs=100, filters=128
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 29, 256)           4352
#
#  conv1d_17 (Conv1D)          (None, 28, 128)           65664
#
#  max_pooling1d_8 (MaxPoolin  (None, 28, 128)           0
#  g1D)
#
#  dropout_8 (Dropout)         (None, 28, 128)           0
#
#  flatten_8 (Flatten)         (None, 3584)              0
#
#  dense_24 (Dense)            (None, 100)               358500
#
#  dense_25 (Dense)            (None, 50)                5050
#
#  dense_26 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 433617 (1.65 MB)
# Trainable params: 433617 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 132/132 [==============================] - 3s 13ms/step - loss: 0.0030 - rmse: 0.0517 - val_loss: 0.0010 - val_rmse: 0.0292
# Epoch 2/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0015 - rmse: 0.0376 - val_loss: 8.8246e-04 - val_rmse: 0.0270
# Epoch 3/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0012 - rmse: 0.0345 - val_loss: 7.8992e-04 - val_rmse: 0.0260
# Epoch 4/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0011 - rmse: 0.0331 - val_loss: 8.2796e-04 - val_rmse: 0.0266
# Epoch 5/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0010 - rmse: 0.0313 - val_loss: 8.9668e-04 - val_rmse: 0.0273
# Epoch 6/100
# 132/132 [==============================] - 0s 3ms/step - loss: 8.7912e-04 - rmse: 0.0293 - val_loss: 8.6915e-04 - val_rmse: 0.0271
# Epoch 7/100
# 132/132 [==============================] - 0s 3ms/step - loss: 7.9597e-04 - rmse: 0.0279 - val_loss: 8.8511e-04 - val_rmse: 0.0274
# Epoch 8/100
# 132/132 [==============================] - 0s 3ms/step - loss: 7.2282e-04 - rmse: 0.0265 - val_loss: 8.6365e-04 - val_rmse: 0.0272
# Epoch 9/100
# 132/132 [==============================] - 0s 3ms/step - loss: 6.4913e-04 - rmse: 0.0251 - val_loss: 9.0452e-04 - val_rmse: 0.0278
# Epoch 10/100
# 132/132 [==============================] - 0s 3ms/step - loss: 5.6336e-04 - rmse: 0.0235 - val_loss: 9.4838e-04 - val_rmse: 0.0285
# Epoch 11/100
# 132/132 [==============================] - 0s 3ms/step - loss: 5.2117e-04 - rmse: 0.0226 - val_loss: 9.5688e-04 - val_rmse: 0.0287
# Epoch 12/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.8704e-04 - rmse: 0.0217 - val_loss: 0.0010 - val_rmse: 0.0296
# Epoch 13/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.3681e-04 - rmse: 0.0206 - val_loss: 0.0010 - val_rmse: 0.0295
# Epoch 14/100
# 132/132 [==============================] - 0s 3ms/step - loss: 3.4818e-04 - rmse: 0.0184 - val_loss: 9.9095e-04 - val_rmse: 0.0292
# Epoch 15/100
# 132/132 [==============================] - 0s 3ms/step - loss: 3.1988e-04 - rmse: 0.0177 - val_loss: 0.0010 - val_rmse: 0.0296
# Epoch 16/100
# 132/132 [==============================] - 0s 3ms/step - loss: 3.3337e-04 - rmse: 0.0178 - val_loss: 0.0011 - val_rmse: 0.0309
# Epoch 17/100
# 132/132 [==============================] - 0s 3ms/step - loss: 2.8533e-04 - rmse: 0.0165 - val_loss: 0.0011 - val_rmse: 0.0315
# Epoch 18/100
# 118/132 [=========================>....] - ETA: 0s - loss: 2.5634e-04 - rmse: 0.0158Restoring model weights from the end of the best epoch: 3.
# 132/132 [==============================] - 0s 3ms/step - loss: 2.5680e-04 - rmse: 0.0157 - val_loss: 0.0011 - val_rmse: 0.0304
# Epoch 18: early stopping
# 26/26 [==============================] - 0s 814us/step
#
# ...
#
# 15) Testing with n_steps=100, batch_size=32, epochs=100, filters=128
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_28 (Conv1D)          (None, 99, 256)           4352
#
#  conv1d_29 (Conv1D)          (None, 98, 128)           65664
#
#  max_pooling1d_14 (MaxPooli  (None, 98, 128)           0
#  ng1D)
#
#  dropout_14 (Dropout)        (None, 98, 128)           0
#
#  flatten_14 (Flatten)        (None, 12544)             0
#
#  dense_42 (Dense)            (None, 100)               1254500
#
#  dense_43 (Dense)            (None, 50)                5050
#
#  dense_44 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1329617 (5.07 MB)
# Trainable params: 1329617 (5.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 131/131 [==============================] - 3s 9ms/step - loss: 0.0035 - rmse: 0.0510 - val_loss: 0.0013 - val_rmse: 0.0345
# Epoch 2/100
# 131/131 [==============================] - 1s 8ms/step - loss: 0.0014 - rmse: 0.0368 - val_loss: 0.0011 - val_rmse: 0.0318
# Epoch 3/100
# 131/131 [==============================] - 1s 8ms/step - loss: 0.0011 - rmse: 0.0326 - val_loss: 0.0012 - val_rmse: 0.0329
# Epoch 4/100
# 131/131 [==============================] - 1s 9ms/step - loss: 9.1020e-04 - rmse: 0.0298 - val_loss: 0.0011 - val_rmse: 0.0315
# Epoch 5/100
# 131/131 [==============================] - 1s 8ms/step - loss: 7.3065e-04 - rmse: 0.0267 - val_loss: 0.0012 - val_rmse: 0.0323
# Epoch 6/100
# 131/131 [==============================] - 1s 8ms/step - loss: 5.9365e-04 - rmse: 0.0241 - val_loss: 0.0012 - val_rmse: 0.0327
# Epoch 7/100
# 131/131 [==============================] - 1s 9ms/step - loss: 5.1550e-04 - rmse: 0.0223 - val_loss: 0.0011 - val_rmse: 0.0314
# Epoch 8/100
# 131/131 [==============================] - 1s 9ms/step - loss: 4.3523e-04 - rmse: 0.0206 - val_loss: 0.0011 - val_rmse: 0.0315
# Epoch 9/100
# 131/131 [==============================] - 1s 9ms/step - loss: 3.7935e-04 - rmse: 0.0191 - val_loss: 0.0010 - val_rmse: 0.0312
# Epoch 10/100
# 131/131 [==============================] - 1s 8ms/step - loss: 3.3986e-04 - rmse: 0.0181 - val_loss: 0.0011 - val_rmse: 0.0313
# Epoch 11/100
# 131/131 [==============================] - 1s 9ms/step - loss: 3.3206e-04 - rmse: 0.0175 - val_loss: 0.0011 - val_rmse: 0.0321
# Epoch 12/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.6372e-04 - rmse: 0.0158 - val_loss: 0.0011 - val_rmse: 0.0326
# Epoch 13/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.3600e-04 - rmse: 0.0150 - val_loss: 0.0012 - val_rmse: 0.0338
# Epoch 14/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.5977e-04 - rmse: 0.0154 - val_loss: 0.0011 - val_rmse: 0.0321
# Epoch 15/100
# 131/131 [==============================] - 1s 9ms/step - loss: 1.9939e-04 - rmse: 0.0136 - val_loss: 0.0010 - val_rmse: 0.0309
100
# 131/131 [==============================] - 1s 9ms/step - loss: 3.5489e-05 - rmse: 0.0057 - val_loss: 9.0384e-04 - val_rmse: 0.0293
# Epoch 78/100
# 131/131 [==============================] - 1s 8ms/step - loss: 3.0107e-05 - rmse: 0.0053 - val_loss: 8.7896e-04 - val_rmse: 0.0288
# Epoch 79/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.9162e-05 - rmse: 0.0052 - val_loss: 8.7298e-04 - val_rmse: 0.0287
# Epoch 80/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.6326e-05 - rmse: 0.0050 - val_loss: 8.8466e-04 - val_rmse: 0.0289
# Epoch 81/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.8764e-05 - rmse: 0.0052 - val_loss: 8.5874e-04 - val_rmse: 0.0285
# Epoch 82/100
# 131/131 [==============================] - 1s 9ms/step - loss: 3.6461e-05 - rmse: 0.0056 - val_loss: 8.9716e-04 - val_rmse: 0.0291
# Epoch 83/100
# 131/131 [==============================] - 1s 9ms/step - loss: 3.9892e-05 - rmse: 0.0058 - val_loss: 8.7014e-04 - val_rmse: 0.0286
# Epoch 84/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.7521e-05 - rmse: 0.0051 - val_loss: 9.0061e-04 - val_rmse: 0.0290
# Epoch 85/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.3092e-05 - rmse: 0.0047 - val_loss: 8.6754e-04 - val_rmse: 0.0286
# Epoch 86/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.2433e-05 - rmse: 0.0046 - val_loss: 8.9117e-04 - val_rmse: 0.0289
# Epoch 87/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.3909e-05 - rmse: 0.0047 - val_loss: 8.6782e-04 - val_rmse: 0.0285
# Epoch 88/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.1960e-05 - rmse: 0.0046 - val_loss: 8.6797e-04 - val_rmse: 0.0285
# Epoch 89/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.2620e-05 - rmse: 0.0046 - val_loss: 8.7246e-04 - val_rmse: 0.0287
# Epoch 90/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.4060e-05 - rmse: 0.0048 - val_loss: 8.8638e-04 - val_rmse: 0.0289
# Epoch 91/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.7442e-05 - rmse: 0.0050 - val_loss: 8.7292e-04 - val_rmse: 0.0286
# Epoch 92/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.4876e-05 - rmse: 0.0048 - val_loss: 8.7199e-04 - val_rmse: 0.0285
# Epoch 93/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.4947e-05 - rmse: 0.0048 - val_loss: 8.8348e-04 - val_rmse: 0.0288
# Epoch 94/100
# 131/131 [==============================] - 1s 9ms/step - loss: 2.8293e-05 - rmse: 0.0050 - val_loss: 8.6690e-04 - val_rmse: 0.0286
# Epoch 95/100
# 131/131 [==============================] - 1s 8ms/step - loss: 2.6620e-05 - rmse: 0.0049 - val_loss: 8.9705e-04 - val_rmse: 0.0291
# Epoch 96/100
# 130/131 [============================>.] - ETA: 0s - loss: 2.3593e-05 - rmse: 0.0047Restoring model weights from the end of the best epoch: 81.
# 131/131 [==============================] - 1s 9ms/step - loss: 2.3567e-05 - rmse: 0.0047 - val_loss: 8.8382e-04 - val_rmse: 0.0288
# Epoch 96: early stopping
# 26/26 [==============================] - 0s 1ms/step
#
# 15) RMSE: 0.031557, Std Dev: 0.029961, Difference: 0.001596
# Tested with n_steps=100, batch_size=32, epochs=100, filters=128
# Model params: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}

# %%
for i, result in enumerate(top_3_results, 1):
    rmse            = result['rmse']
    model_params    = result['params']
    history         = result['history']
    batch_size      = result['batch_size']
    n_steps         = result['n_steps']
    y_test          = result['actuals']
    y_pred          = result['predictions']
    diff = result['difference']

    print(f"\nTop {i} Model")
    print(f"Best RMSE: {rmse:.6f} vs. a std of {y_test.std():.6f}, diff = {diff:.6f}")
    print(f"Model parameters: {model_params}")
    print(f"n_steps: {n_steps}, batch_size: {batch_size}")

    # plot_history(history)

    plot_predictions(y_test, y_pred, 100, title=f"Top {i} Model Predictions vs Actual")
    # plot_predictions(y_test, y_pred*-1, 100, title=f"Top {i} Model Predictions vs Actual")

    # print the values of predictions and actuals one next to the other(only the first 10)
    # for pred, actual in zip(y_pred[:10], y_test[:10]):
    #     print(f"Predicted: {pred[0]:.6f}, Actual: {actual:.6f}")
# Out:
# Top 1 Model
# Best RMSE: 0.031233 vs. a std of 0.029961, diff = 0.001272
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 100, batch_size: 16
# Top 2 Model
# Best RMSE: 0.032154 vs. a std of 0.030634, diff = 0.001520
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 20, batch_size: 8
# Top 3 Model
# Best RMSE: 0.031532 vs. a std of 0.029961, diff = 0.001571
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 100, batch_size: 8
# Top 4 Model
# Best RMSE: 0.031557 vs. a std of 0.029961, diff = 0.001596
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 100, batch_size: 32
# Top 5 Model
# Best RMSE: 0.032169 vs. a std of 0.030553, diff = 0.001615
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 50, batch_size: 8
# Top 6 Model
# Best RMSE: 0.033131 vs. a std of 0.030613, diff = 0.002518
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 16
# Top 7 Model
# Best RMSE: 0.033207 vs. a std of 0.030667, diff = 0.002539
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 10, batch_size: 32
# Top 8 Model
# Best RMSE: 0.033215 vs. a std of 0.030613, diff = 0.002602
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 32
# Top 9 Model
# Best RMSE: 0.033329 vs. a std of 0.030553, diff = 0.002775
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 50, batch_size: 32
# Top 10 Model
# Best RMSE: 0.033377 vs. a std of 0.030553, diff = 0.002824
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 50, batch_size: 16
# Top 11 Model
# Best RMSE: 0.033443 vs. a std of 0.030613, diff = 0.002830
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 30, batch_size: 8
# Top 12 Model
# Best RMSE: 0.033789 vs. a std of 0.030667, diff = 0.003122
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 10, batch_size: 8
# Top 13 Model
# Best RMSE: 0.033768 vs. a std of 0.030634, diff = 0.003133
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 20, batch_size: 16
# Top 14 Model
# Best RMSE: 0.033882 vs. a std of 0.030634, diff = 0.003248
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 20, batch_size: 32
# Top 15 Model
# Best RMSE: 0.034365 vs. a std of 0.030667, diff = 0.003698
# Model parameters: {'filters': 128, 'kernel_size': 2, 'pool_size': 1, 'dense_units': 50, 'dense_activation': 'relu', 'activation': 'relu', 'dropout': 0.1}
# n_steps: 10, batch_size: 16

# %%
"""n_steps_options     = [15]
batch_size_options  = [16]
epochs_options      = [100]

filters_options         = [64, 128, 256]
kernel_size_options     = [2, 3, 5]
pool_size_options       = [1, 2]
dense_units_options     = [50, 100, 150]
# dense_activation_options = ['relu', 'tanh']
dense_activation_options = ['relu']
# activation_options      = ['relu', 'tanh']
activation_options      = ['relu']
dropout_options         = [0.1, 0.2, 0.3]"""
# Out:
# "n_steps_options     = [15]\nbatch_size_options  = [16]\nepochs_options      = [100]\n\nfilters_options         = [64, 128, 256]\nkernel_size_options     = [2, 3, 5]\npool_size_options       = [1, 2]\ndense_units_options     = [50, 100, 150]\n# dense_activation_options = ['relu', 'tanh']\ndense_activation_options = ['relu']\n# activation_options      = ['relu', 'tanh']\nactivation_options      = ['relu']\ndropout_options         = [0.1, 0.2, 0.3]"
